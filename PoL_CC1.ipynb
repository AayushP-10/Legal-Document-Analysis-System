# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.42.73-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.43.0,>=1.42.73 (from boto3)
#   Downloading botocore-1.42.73-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.73->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.73->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.73->boto3) (1.17.0)
# Downloading boto3-1.42.73-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 14.8 MB/s eta 0:00:00
# Downloading botocore-1.42.73-py3-none-any.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 142.9 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.73 botocore-1.42.73 jmespath-1.1.0 s3transfer-0.16.0

# %%
import os
import hashlib
from typing import List, Dict, Iterable

import boto3
import pyarrow.parquet as pq
from botocore.config import Config
from botocore.exceptions import ClientError
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer
from google.colab import userdata


# ================= CONFIG =================
AWS_ACCESS_KEY_ID = userdata.get("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = userdata.get("AWS_SECRET_ACCESS_KEY")
AWS_REGION = userdata.get("AWS_DEFAULT_REGION") or "us-east-2"

SOURCE_BUCKET = "cleaned-legal-data-analysis-src-v2"
PARQUET_KEY = "pile_of_law/cleaned_contracts_3.parquet"

TARGET_VECTOR_BUCKET = "combined.embeddings"
TARGET_INDEX_NAME = "legal-combined-index"

MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"

MAX_TOKENS = 350
OVERLAP = 75

EMBED_BATCH = 512
BUFFER_SIZE = 2000
PUT_BATCH = 100
GET_EXISTING_BATCH = 100

LOCAL_PARQUET_PATH = "/tmp/pile_of_law_current.parquet"


# ================= AWS SESSION =================
session = boto3.Session(
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    region_name=AWS_REGION,
)

cfg = Config(retries={"max_attempts": 10, "mode": "standard"})
s3 = session.client("s3", config=cfg)
vec = session.client("s3vectors", config=cfg)


# ================= MODEL =================
print("Loading model on GPU...")
model = SentenceTransformer(MODEL_NAME, device="cuda")
model = model.half()
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)


# ================= HELPERS =================
def clean_text(x) -> str:
    return " ".join(str(x).replace("\x00", " ").split()).strip()


def chunk_text(text: str) -> List[str]:
    text = clean_text(text)
    if not text:
        return []

    token_ids = tokenizer(
        text,
        add_special_tokens=False,
        truncation=False,
        return_attention_mask=False,
        return_token_type_ids=False,
    )["input_ids"]

    if not token_ids:
        return []

    if len(token_ids) <= MAX_TOKENS:
        chunk = tokenizer.decode(token_ids, skip_special_tokens=True).strip()
        return [chunk] if chunk else []

    chunks = []
    step = MAX_TOKENS - OVERLAP

    for start in range(0, len(token_ids), step):
        end = start + MAX_TOKENS
        piece = token_ids[start:end]
        if not piece:
            continue

        chunk = tokenizer.decode(piece, skip_special_tokens=True).strip()
        if chunk:
            chunks.append(chunk)

        if end >= len(token_ids):
            break

    return chunks


def make_vector_key(
    dataset: str,
    parquet_key: str,
    row_group_idx: int,
    row_idx: int,
    chunk_idx: int,
    doc_id: str,
    chunk_text_value: str,
) -> str:
    base = f"{dataset}|{parquet_key}|rg={row_group_idx}|row={row_idx}|chunk={chunk_idx}|doc={doc_id}"
    base_hash = hashlib.md5(base.encode("utf-8")).hexdigest()[:20]
    text_hash = hashlib.md5(chunk_text_value.encode("utf-8")).hexdigest()[:12]
    return f"{dataset}::{base_hash}::{text_hash}"


def batched(items: List, size: int) -> Iterable[List]:
    for i in range(0, len(items), size):
        yield items[i:i + size]


def ensure_vector_bucket_and_index() -> None:
    bucket_exists = True
    try:
        vec.get_vector_bucket(vectorBucketName=TARGET_VECTOR_BUCKET)
    except ClientError as e:
        code = e.response.get("Error", {}).get("Code", "")
        if code in {"NotFoundException", "ResourceNotFoundException"}:
            bucket_exists = False
        else:
            raise

    if not bucket_exists:
        vec.create_vector_bucket(vectorBucketName=TARGET_VECTOR_BUCKET)

    index_exists = True
    try:
        vec.get_index(
            vectorBucketName=TARGET_VECTOR_BUCKET,
            indexName=TARGET_INDEX_NAME,
        )
    except ClientError as e:
        code = e.response.get("Error", {}).get("Code", "")
        if code in {"NotFoundException", "ResourceNotFoundException"}:
            index_exists = False
        else:
            raise

    if not index_exists:
        vec.create_index(
            vectorBucketName=TARGET_VECTOR_BUCKET,
            indexName=TARGET_INDEX_NAME,
            dataType="float32",
            dimension=384,
            distanceMetric="cosine",
        )


def existing_keys(keys: List[str]) -> set:
    found = set()

    for batch in batched(keys, GET_EXISTING_BATCH):
        try:
            resp = vec.get_vectors(
                vectorBucketName=TARGET_VECTOR_BUCKET,
                indexName=TARGET_INDEX_NAME,
                keys=batch,
            )
            for item in resp.get("vectors", []):
                k = item.get("key")
                if k:
                    found.add(k)
        except ClientError:
            pass

    return found


def put_vectors(vectors: List[Dict]) -> None:
    for batch in batched(vectors, PUT_BATCH):
        vec.put_vectors(
            vectorBucketName=TARGET_VECTOR_BUCKET,
            indexName=TARGET_INDEX_NAME,
            vectors=batch,
        )


def flush_buffer(buffer: List[Dict], stats: Dict[str, int]) -> List[Dict]:
    if not buffer:
        return []

    unique_map = {}
    for row in buffer:
        unique_map[row["key"]] = row
    unique_rows = list(unique_map.values())

    stats["attempted"] += len(unique_rows)

    keys = [row["key"] for row in unique_rows]
    already = existing_keys(keys)

    to_insert = [row for row in unique_rows if row["key"] not in already]
    skipped = len(unique_rows) - len(to_insert)
    stats["skipped"] += skipped

    if not to_insert:
        print(
            f"Inserted={stats['inserted']}  "
            f"Skipped={stats['skipped']}  "
            f"Attempted={stats['attempted']}"
        )
        return []

    texts = [row["text"] for row in to_insert]
    embeddings = model.encode(
        texts,
        batch_size=EMBED_BATCH,
        normalize_embeddings=True,
        show_progress_bar=False,
    )

    payload = []
    seen_payload = set()

    for row, emb in zip(to_insert, embeddings):
        key = row["key"]
        if key in seen_payload:
            continue
        seen_payload.add(key)

        payload.append(
            {
                "key": key,
                "data": {"float32": [float(x) for x in emb]},
                "metadata": {
                    "dataset": "pile_of_law",
                    "doc_id": row["doc_id"][:200],
                    "source_uri": row["source_uri"][:500],
                },
            }
        )

    if payload:
        put_vectors(payload)
        stats["inserted"] += len(payload)

    print(
        f"Inserted={stats['inserted']}  "
        f"Skipped={stats['skipped']}  "
        f"Attempted={stats['attempted']}"
    )
    return []


# ================= MAIN =================
def main():
    if not AWS_ACCESS_KEY_ID or not AWS_SECRET_ACCESS_KEY:
        raise ValueError("AWS credentials not found in Colab secrets.")

    print("Ensuring target vector bucket and index exist...")
    ensure_vector_bucket_and_index()

    print(f"Downloading parquet from s3://{SOURCE_BUCKET}/{PARQUET_KEY}")
    s3.download_file(SOURCE_BUCKET, PARQUET_KEY, LOCAL_PARQUET_PATH)
    print(f"Local file ready: {LOCAL_PARQUET_PATH}")

    parquet_file = pq.ParquetFile(LOCAL_PARQUET_PATH)

    stats = {
        "row_groups": parquet_file.num_row_groups,
        "rows_seen": 0,
        "chunks_seen": 0,
        "attempted": 0,
        "inserted": 0,
        "skipped": 0,
    }

    buffer = []
    source_uri = f"s3://{SOURCE_BUCKET}/{PARQUET_KEY}"

    print("Processing parquet row groups...")
    for rg_idx in range(parquet_file.num_row_groups):
        table = parquet_file.read_row_group(rg_idx)
        rows = table.to_pylist()

        for row_idx, row in enumerate(rows):
            stats["rows_seen"] += 1

            text = clean_text(
                row.get("text")
                or row.get("cleaned_text")
                or row.get("content")
                or row.get("body")
                or ""
            )
            if not text:
                continue

            doc_id = clean_text(
                row.get("doc_id")
                or row.get("document_id")
                or row.get("contract_id")
                or row.get("file_id")
                or row.get("id")
                or f"doc_{rg_idx}_{row_idx}"
            )

            chunks = chunk_text(text)
            if not chunks:
                continue

            for chunk_idx, chunk_value in enumerate(chunks):
                stats["chunks_seen"] += 1
                key = make_vector_key(
                    dataset="pile_of_law",
                    parquet_key=PARQUET_KEY,
                    row_group_idx=rg_idx,
                    row_idx=row_idx,
                    chunk_idx=chunk_idx,
                    doc_id=doc_id,
                    chunk_text_value=chunk_value,
                )

                buffer.append(
                    {
                        "key": key,
                        "doc_id": doc_id,
                        "text": chunk_value,
                        "source_uri": source_uri,
                    }
                )

            if len(buffer) >= BUFFER_SIZE:
                buffer = flush_buffer(buffer, stats)

    if buffer:
        buffer = flush_buffer(buffer, stats)

    print("\nDone.")
    print(f"Row groups       : {stats['row_groups']}")
    print(f"Rows seen        : {stats['rows_seen']}")
    print(f"Chunks seen      : {stats['chunks_seen']}")
    print(f"Attempted chunks : {stats['attempted']}")
    print(f"Inserted chunks  : {stats['inserted']}")
    print(f"Skipped existing : {stats['skipped']}")


if __name__ == "__main__":
    main()
# Out:
# Loading model on GPU...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Ensuring target vector bucket and index exist...
# Downloading parquet from s3://cleaned-legal-data-analysis-src-v2/pile_of_law/cleaned_contracts_3.parquet
# Local file ready: /tmp/pile_of_law_current.parquet
# Processing parquet row groups...
# Token indices sequence length is longer than the specified maximum sequence length for this model (1275 > 512). Running this sequence through the model will result in indexing errors
# Inserted=2002  Skipped=0  Attempted=2002
# Inserted=4002  Skipped=0  Attempted=4002
# Inserted=6003  Skipped=0  Attempted=6003
# Inserted=8003  Skipped=0  Attempted=8003
# Inserted=10004  Skipped=0  Attempted=10004
# Inserted=12004  Skipped=0  Attempted=12004
# Inserted=14008  Skipped=0  Attempted=14008
# Inserted=16008  Skipped=0  Attempted=16008
# Inserted=18009  Skipped=0  Attempted=18009
# Inserted=20011  Skipped=0  Attempted=20011
# Inserted=22014  Skipped=0  Attempted=22014
# Inserted=24018  Skipped=0  Attempted=24018
# Inserted=26018  Skipped=0  Attempted=26018
# Inserted=28018  Skipped=0  Attempted=28018
# Inserted=30021  Skipped=0  Attempted=30021
# Inserted=32025  Skipped=0  Attempted=32025
# Inserted=34026  Skipped=0  Attempted=34026
# Inserted=36028  Skipped=0  Attempted=36028
# Inserted=38028  Skipped=0  Attempted=38028
# Inserted=40029  Skipped=0  Attempted=40029
# Inserted=42029  Skipped=0  Attempted=42029
# Inserted=44031  Skipped=0  Attempted=44031
# Inserted=46033  Skipped=0  Attempted=46033
# Inserted=48033  Skipped=0  Attempted=48033
# Inserted=50033  Skipped=0  Attempted=50033
# Inserted=52037  Skipped=0  Attempted=52037
# Inserted=54041  Skipped=0  Attempted=54041
# Inserted=56045  Skipped=0  Attempted=56045
# Inserted=58045  Skipped=0  Attempted=58045
# Inserted=60047  Skipped=0  Attempted=60047
# Inserted=62047  Skipped=0  Attempted=62047
# Inserted=64048  Skipped=0  Attempted=64048
# Inserted=66049  Skipped=0  Attempted=66049
# Inserted=68049  Skipped=0  Attempted=68049
# Inserted=70053  Skipped=0  Attempted=70053
# Inserted=72056  Skipped=0  Attempted=72056
# Inserted=74056  Skipped=0  Attempted=74056
# Inserted=76056  Skipped=0  Attempted=76056
# Inserted=78058  Skipped=0  Attempted=78058
# Inserted=80058  Skipped=0  Attempted=80058
# Inserted=82061  Skipped=0  Attempted=82061
# Inserted=84063  Skipped=0  Attempted=84063
# Inserted=86064  Skipped=0  Attempted=86064
# Inserted=88064  Skipped=0  Attempted=88064
# Inserted=90064  Skipped=0  Attempted=90064
# Inserted=92067  Skipped=0  Attempted=92067
# Inserted=94068  Skipped=0  Attempted=94068
# Inserted=96071  Skipped=0  Attempted=96071
# Inserted=98071  Skipped=0  Attempted=98071
# Inserted=100073  Skipped=0  Attempted=100073
# Inserted=102075  Skipped=0  Attempted=102075
# Inserted=104077  Skipped=0  Attempted=104077
# Inserted=106078  Skipped=0  Attempted=106078
# Inserted=108079  Skipped=0  Attempted=108079
# Inserted=110080  Skipped=0  Attempted=110080
# Inserted=112082  Skipped=0  Attempted=112082
# Inserted=114082  Skipped=0  Attempted=114082
# Inserted=116083  Skipped=0  Attempted=116083
# Inserted=118083  Skipped=0  Attempted=118083
# Inserted=120086  Skipped=0  Attempted=120086
# Inserted=122086  Skipped=0  Attempted=122086
# Inserted=124088  Skipped=0  Attempted=124088
# Inserted=126088  Skipped=0  Attempted=126088
# Inserted=128089  Skipped=0  Attempted=128089
# Inserted=130089  Skipped=0  Attempted=130089
# Inserted=132090  Skipped=0  Attempted=132090
# Inserted=134090  Skipped=0  Attempted=134090
# Inserted=136092  Skipped=0  Attempted=136092
# Inserted=138092  Skipped=0  Attempted=138092
# Inserted=140094  Skipped=0  Attempted=140094
# Inserted=142097  Skipped=0  Attempted=142097
# Inserted=144100  Skipped=0  Attempted=144100
# Inserted=146103  Skipped=0  Attempted=146103
# Inserted=148103  Skipped=0  Attempted=148103
# Inserted=150107  Skipped=0  Attempted=150107
# Inserted=152108  Skipped=0  Attempted=152108
# Inserted=154110  Skipped=0  Attempted=154110
# Inserted=156111  Skipped=0  Attempted=156111
# Inserted=158111  Skipped=0  Attempted=158111
# Inserted=160114  Skipped=0  Attempted=160114
# Inserted=162114  Skipped=0  Attempted=162114
# Inserted=164115  Skipped=0  Attempted=164115
# Inserted=166115  Skipped=0  Attempted=166115
# Inserted=168118  Skipped=0  Attempted=168118
# Inserted=170118  Skipped=0  Attempted=170118
# Inserted=172119  Skipped=0  Attempted=172119
# Inserted=174119  Skipped=0  Attempted=174119
# Inserted=176124  Skipped=0  Attempted=176124
# Inserted=178124  Skipped=0  Attempted=178124
# Inserted=180124  Skipped=0  Attempted=180124
# Inserted=182125  Skipped=0  Attempted=182125
# Inserted=184125  Skipped=0  Attempted=184125
# Inserted=186128  Skipped=0  Attempted=186128
# Inserted=188129  Skipped=0  Attempted=188129
# Inserted=190129  Skipped=0  Attempted=190129
# Inserted=192130  Skipped=0  Attempted=192130
# Inserted=194130  Skipped=0  Attempted=194130
# Inserted=196133  Skipped=0  Attempted=196133
# Inserted=198133  Skipped=0  Attempted=198133
# Inserted=200133  Skipped=0  Attempted=200133
# Inserted=202134  Skipped=0  Attempted=202134
# Inserted=204134  Skipped=0  Attempted=204134
# Inserted=206134  Skipped=0  Attempted=206134
# Inserted=208134  Skipped=0  Attempted=208134
# Inserted=210135  Skipped=0  Attempted=210135
# Inserted=212137  Skipped=0  Attempted=212137
# Inserted=214140  Skipped=0  Attempted=214140
# Inserted=216143  Skipped=0  Attempted=216143
# Inserted=218144  Skipped=0  Attempted=218144
# Inserted=220145  Skipped=0  Attempted=220145
# Inserted=222149  Skipped=0  Attempted=222149
# Inserted=224153  Skipped=0  Attempted=224153
# Inserted=226162  Skipped=0  Attempted=226162
# Inserted=228164  Skipped=0  Attempted=228164
# Inserted=230165  Skipped=0  Attempted=230165
# Inserted=232167  Skipped=0  Attempted=232167
# Inserted=234170  Skipped=0  Attempted=234170
# Inserted=236170  Skipped=0  Attempted=236170
# Inserted=238170  Skipped=0  Attempted=238170
# Inserted=240173  Skipped=0  Attempted=240173
# Inserted=242173  Skipped=0  Attempted=242173
# Inserted=244177  Skipped=0  Attempted=244177
# Inserted=246177  Skipped=0  Attempted=246177
# Inserted=248177  Skipped=0  Attempted=248177
# Inserted=250180  Skipped=0  Attempted=250180
# Inserted=252184  Skipped=0  Attempted=252184
# Inserted=254184  Skipped=0  Attempted=254184
# Inserted=256188  Skipped=0  Attempted=256188
# Inserted=258190  Skipped=0  Attempted=258190
# Inserted=260190  Skipped=0  Attempted=260190
# Inserted=262194  Skipped=0  Attempted=262194
# Inserted=264196  Skipped=0  Attempted=264196
# Inserted=266199  Skipped=0  Attempted=266199
# Inserted=268204  Skipped=0  Attempted=268204
# Inserted=270204  Skipped=0  Attempted=270204
# Inserted=272205  Skipped=0  Attempted=272205
# Inserted=274205  Skipped=0  Attempted=274205
# Inserted=276208  Skipped=0  Attempted=276208
# Inserted=278209  Skipped=0  Attempted=278209
# Inserted=280209  Skipped=0  Attempted=280209
# Inserted=282211  Skipped=0  Attempted=282211
# Inserted=284211  Skipped=0  Attempted=284211
# Inserted=286213  Skipped=0  Attempted=286213
# Inserted=288216  Skipped=0  Attempted=288216
# Inserted=290219  Skipped=0  Attempted=290219
# Inserted=292219  Skipped=0  Attempted=292219
# Inserted=294219  Skipped=0  Attempted=294219
# Inserted=296221  Skipped=0  Attempted=296221
# Inserted=298223  Skipped=0  Attempted=298223
# Inserted=300225  Skipped=0  Attempted=300225
# Inserted=302225  Skipped=0  Attempted=302225
# Inserted=304227  Skipped=0  Attempted=304227
# Inserted=306227  Skipped=0  Attempted=306227
# Inserted=308230  Skipped=0  Attempted=308230
# Inserted=310231  Skipped=0  Attempted=310231
# Inserted=312231  Skipped=0  Attempted=312231
# Inserted=314232  Skipped=0  Attempted=314232
# Inserted=316232  Skipped=0  Attempted=316232
# Inserted=318235  Skipped=0  Attempted=318235
# Inserted=320238  Skipped=0  Attempted=320238
# Inserted=322239  Skipped=0  Attempted=322239
# Inserted=324240  Skipped=0  Attempted=324240
# Inserted=326243  Skipped=0  Attempted=326243
# Inserted=328247  Skipped=0  Attempted=328247
# Inserted=330247  Skipped=0  Attempted=330247
# Inserted=332247  Skipped=0  Attempted=332247
# Inserted=334250  Skipped=0  Attempted=334250
# Inserted=336250  Skipped=0  Attempted=336250
# Inserted=338250  Skipped=0  Attempted=338250
# Inserted=340251  Skipped=0  Attempted=340251
# Inserted=342252  Skipped=0  Attempted=342252
# Inserted=344253  Skipped=0  Attempted=344253
# Inserted=346254  Skipped=0  Attempted=346254
# Inserted=348255  Skipped=0  Attempted=348255
# Inserted=350255  Skipped=0  Attempted=350255
# Inserted=352258  Skipped=0  Attempted=352258
# Inserted=354259  Skipped=0  Attempted=354259
# Inserted=356261  Skipped=0  Attempted=356261
# Inserted=358265  Skipped=0  Attempted=358265
# Inserted=360269  Skipped=0  Attempted=360269
# Inserted=362269  Skipped=0  Attempted=362269
# Inserted=364269  Skipped=0  Attempted=364269
# Inserted=366271  Skipped=0  Attempted=366271
# Inserted=368272  Skipped=0  Attempted=368272
# Inserted=370272  Skipped=0  Attempted=370272
# Inserted=372275  Skipped=0  Attempted=372275
# Inserted=374278  Skipped=0  Attempted=374278
# Inserted=376278  Skipped=0  Attempted=376278
# Inserted=378279  Skipped=0  Attempted=378279
# Inserted=380282  Skipped=0  Attempted=380282
# Inserted=382286  Skipped=0  Attempted=382286
# Inserted=384286  Skipped=0  Attempted=384286
# Inserted=386287  Skipped=0  Attempted=386287
# Inserted=388290  Skipped=0  Attempted=388290
# Inserted=390292  Skipped=0  Attempted=390292
# Inserted=392295  Skipped=0  Attempted=392295
# Inserted=394295  Skipped=0  Attempted=394295
# Inserted=396299  Skipped=0  Attempted=396299
# Inserted=398300  Skipped=0  Attempted=398300
# Inserted=400300  Skipped=0  Attempted=400300
# Inserted=402301  Skipped=0  Attempted=402301
# Inserted=404302  Skipped=0  Attempted=404302
# Inserted=406305  Skipped=0  Attempted=406305
# Inserted=408305  Skipped=0  Attempted=408305
# Inserted=410309  Skipped=0  Attempted=410309
# Inserted=412311  Skipped=0  Attempted=412311
# Inserted=414311  Skipped=0  Attempted=414311
# Inserted=416313  Skipped=0  Attempted=416313
# Inserted=418313  Skipped=0  Attempted=418313
# Inserted=420315  Skipped=0  Attempted=420315
# Inserted=422315  Skipped=0  Attempted=422315
# Inserted=424318  Skipped=0  Attempted=424318
# Inserted=426318  Skipped=0  Attempted=426318
# Inserted=428318  Skipped=0  Attempted=428318
# Inserted=430318  Skipped=0  Attempted=430318
# Inserted=432318  Skipped=0  Attempted=432318
# Inserted=434318  Skipped=0  Attempted=434318
# Inserted=436320  Skipped=0  Attempted=436320
# Inserted=438321  Skipped=0  Attempted=438321
# Inserted=440324  Skipped=0  Attempted=440324
# Inserted=442324  Skipped=0  Attempted=442324
# Inserted=444324  Skipped=0  Attempted=444324
# Inserted=446325  Skipped=0  Attempted=446325
# Inserted=448329  Skipped=0  Attempted=448329
# Inserted=450329  Skipped=0  Attempted=450329
# Inserted=452330  Skipped=0  Attempted=452330
# Inserted=454334  Skipped=0  Attempted=454334
# Inserted=456334  Skipped=0  Attempted=456334
# Inserted=458335  Skipped=0  Attempted=458335
# Inserted=460335  Skipped=0  Attempted=460335
# Inserted=462338  Skipped=0  Attempted=462338
# Inserted=464340  Skipped=0  Attempted=464340
# Inserted=466340  Skipped=0  Attempted=466340
# Inserted=468341  Skipped=0  Attempted=468341
# Inserted=470341  Skipped=0  Attempted=470341
# Inserted=472341  Skipped=0  Attempted=472341
# Inserted=474342  Skipped=0  Attempted=474342
# Inserted=476342  Skipped=0  Attempted=476342
# Inserted=478343  Skipped=0  Attempted=478343
# Inserted=480347  Skipped=0  Attempted=480347
# Inserted=482347  Skipped=0  Attempted=482347
# Inserted=484349  Skipped=0  Attempted=484349
# Inserted=486349  Skipped=0  Attempted=486349
# Inserted=488349  Skipped=0  Attempted=488349
# Inserted=490351  Skipped=0  Attempted=490351
# Inserted=492351  Skipped=0  Attempted=492351
# Inserted=494351  Skipped=0  Attempted=494351
# Inserted=496351  Skipped=0  Attempted=496351
# Inserted=498353  Skipped=0  Attempted=498353
# Inserted=500356  Skipped=0  Attempted=500356
# Inserted=502356  Skipped=0  Attempted=502356
# Inserted=504356  Skipped=0  Attempted=504356
# Inserted=506356  Skipped=0  Attempted=506356
# Inserted=508356  Skipped=0  Attempted=508356
# Inserted=510357  Skipped=0  Attempted=510357
# Inserted=512359  Skipped=0  Attempted=512359
# Inserted=514359  Skipped=0  Attempted=514359
# Inserted=516361  Skipped=0  Attempted=516361
# Inserted=518361  Skipped=0  Attempted=518361
# Inserted=520361  Skipped=0  Attempted=520361
# Inserted=522361  Skipped=0  Attempted=522361
# Inserted=524362  Skipped=0  Attempted=524362
# Inserted=526364  Skipped=0  Attempted=526364
# Inserted=528366  Skipped=0  Attempted=528366
# Inserted=530370  Skipped=0  Attempted=530370
# Inserted=532370  Skipped=0  Attempted=532370
# Inserted=534371  Skipped=0  Attempted=534371
# Inserted=536373  Skipped=0  Attempted=536373
# Inserted=538373  Skipped=0  Attempted=538373
# Inserted=540377  Skipped=0  Attempted=540377
# Inserted=542378  Skipped=0  Attempted=542378
# Inserted=544379  Skipped=0  Attempted=544379
# Inserted=546379  Skipped=0  Attempted=546379
# Inserted=548382  Skipped=0  Attempted=548382
# Inserted=550383  Skipped=0  Attempted=550383
# Inserted=552386  Skipped=0  Attempted=552386
# Inserted=554386  Skipped=0  Attempted=554386
# Inserted=556389  Skipped=0  Attempted=556389
# Inserted=558389  Skipped=0  Attempted=558389
# Inserted=560390  Skipped=0  Attempted=560390
# Inserted=562394  Skipped=0  Attempted=562394
# Inserted=564394  Skipped=0  Attempted=564394
# Inserted=566395  Skipped=0  Attempted=566395
# Inserted=568396  Skipped=0  Attempted=568396
# Inserted=570398  Skipped=0  Attempted=570398
# Inserted=572398  Skipped=0  Attempted=572398
# Inserted=574399  Skipped=0  Attempted=574399
# Inserted=576399  Skipped=0  Attempted=576399
# Inserted=578399  Skipped=0  Attempted=578399
# Inserted=580401  Skipped=0  Attempted=580401
# Inserted=582403  Skipped=0  Attempted=582403
# Inserted=584406  Skipped=0  Attempted=584406
# Inserted=586409  Skipped=0  Attempted=586409
# Inserted=588412  Skipped=0  Attempted=588412
# Inserted=590412  Skipped=0  Attempted=590412
# Inserted=592412  Skipped=0  Attempted=592412
# Inserted=594412  Skipped=0  Attempted=594412
# Inserted=596413  Skipped=0  Attempted=596413
# Inserted=598415  Skipped=0  Attempted=598415
# Inserted=600417  Skipped=0  Attempted=600417
# Inserted=602418  Skipped=0  Attempted=602418
# Inserted=604418  Skipped=0  Attempted=604418
# Inserted=606419  Skipped=0  Attempted=606419
# Inserted=608419  Skipped=0  Attempted=608419
# Inserted=610421  Skipped=0  Attempted=610421
# Inserted=612424  Skipped=0  Attempted=612424
# Inserted=614426  Skipped=0  Attempted=614426
# Inserted=616427  Skipped=0  Attempted=616427
# Inserted=618428  Skipped=0  Attempted=618428
# Inserted=620428  Skipped=0  Attempted=620428
# Inserted=622428  Skipped=0  Attempted=622428
# Inserted=624429  Skipped=0  Attempted=624429
# Inserted=626432  Skipped=0  Attempted=626432
# Inserted=628433  Skipped=0  Attempted=628433
# Inserted=630437  Skipped=0  Attempted=630437
# Inserted=632441  Skipped=0  Attempted=632441
# Inserted=634443  Skipped=0  Attempted=634443
# Inserted=636443  Skipped=0  Attempted=636443
# Inserted=638443  Skipped=0  Attempted=638443
# Inserted=640446  Skipped=0  Attempted=640446
# Inserted=642446  Skipped=0  Attempted=642446
# Inserted=644451  Skipped=0  Attempted=644451
# Inserted=646452  Skipped=0  Attempted=646452
# Inserted=648452  Skipped=0  Attempted=648452
# Inserted=650456  Skipped=0  Attempted=650456
# Inserted=652456  Skipped=0  Attempted=652456
# Inserted=654456  Skipped=0  Attempted=654456
# Inserted=656456  Skipped=0  Attempted=656456
# Inserted=658457  Skipped=0  Attempted=658457
# Inserted=660457  Skipped=0  Attempted=660457
# Inserted=662457  Skipped=0  Attempted=662457
# Inserted=664460  Skipped=0  Attempted=664460
# Inserted=666464  Skipped=0  Attempted=666464
# Inserted=668464  Skipped=0  Attempted=668464
# Inserted=670464  Skipped=0  Attempted=670464
# Inserted=672464  Skipped=0  Attempted=672464
# Inserted=674464  Skipped=0  Attempted=674464
# Inserted=676468  Skipped=0  Attempted=676468
# Inserted=678470  Skipped=0  Attempted=678470
# Inserted=680470  Skipped=0  Attempted=680470
# Inserted=682474  Skipped=0  Attempted=682474
# Inserted=684478  Skipped=0  Attempted=684478
# Inserted=686479  Skipped=0  Attempted=686479
# Inserted=688483  Skipped=0  Attempted=688483
# Inserted=690484  Skipped=0  Attempted=690484
# Inserted=692487  Skipped=0  Attempted=692487
# Inserted=694489  Skipped=0  Attempted=694489
# Inserted=696494  Skipped=0  Attempted=696494
# Inserted=698494  Skipped=0  Attempted=698494
# Inserted=700494  Skipped=0  Attempted=700494
# Inserted=702494  Skipped=0  Attempted=702494
# Inserted=704497  Skipped=0  Attempted=704497
# Inserted=706499  Skipped=0  Attempted=706499
# Inserted=708502  Skipped=0  Attempted=708502
# Inserted=710503  Skipped=0  Attempted=710503
# Inserted=712503  Skipped=0  Attempted=712503
# Inserted=714503  Skipped=0  Attempted=714503
# Inserted=716504  Skipped=0  Attempted=716504
# Inserted=718507  Skipped=0  Attempted=718507
# Inserted=720510  Skipped=0  Attempted=720510
# Inserted=722514  Skipped=0  Attempted=722514
# Inserted=724517  Skipped=0  Attempted=724517
# Inserted=726520  Skipped=0  Attempted=726520
# Inserted=728520  Skipped=0  Attempted=728520
# Inserted=730524  Skipped=0  Attempted=730524
# Inserted=732528  Skipped=0  Attempted=732528
# Inserted=734530  Skipped=0  Attempted=734530
# Inserted=736533  Skipped=0  Attempted=736533
# Inserted=738533  Skipped=0  Attempted=738533
# Inserted=740533  Skipped=0  Attempted=740533
# Inserted=742534  Skipped=0  Attempted=742534
# Inserted=744537  Skipped=0  Attempted=744537
# Inserted=746537  Skipped=0  Attempted=746537
# Inserted=748540  Skipped=0  Attempted=748540
# Inserted=750540  Skipped=0  Attempted=750540
# Inserted=752540  Skipped=0  Attempted=752540
# Inserted=754541  Skipped=0  Attempted=754541
# Inserted=756542  Skipped=0  Attempted=756542
# Inserted=758543  Skipped=0  Attempted=758543
# Inserted=760544  Skipped=0  Attempted=760544
# Inserted=762544  Skipped=0  Attempted=762544
# Inserted=764544  Skipped=0  Attempted=764544
# Inserted=766545  Skipped=0  Attempted=766545
# Inserted=768547  Skipped=0  Attempted=768547
# Inserted=770547  Skipped=0  Attempted=770547
# Inserted=772550  Skipped=0  Attempted=772550
# Inserted=774550  Skipped=0  Attempted=774550
# Inserted=776552  Skipped=0  Attempted=776552
# Inserted=778552  Skipped=0  Attempted=778552
# Inserted=780556  Skipped=0  Attempted=780556
# Inserted=782559  Skipped=0  Attempted=782559
# Inserted=784561  Skipped=0  Attempted=784561
# Inserted=786561  Skipped=0  Attempted=786561
# Inserted=788569  Skipped=0  Attempted=788569
# Inserted=790569  Skipped=0  Attempted=790569
# Inserted=792571  Skipped=0  Attempted=792571
# Inserted=794571  Skipped=0  Attempted=794571
# Inserted=796571  Skipped=0  Attempted=796571
# Inserted=798571  Skipped=0  Attempted=798571
# Inserted=800571  Skipped=0  Attempted=800571
# Inserted=802575  Skipped=0  Attempted=802575
# Inserted=804576  Skipped=0  Attempted=804576
# Inserted=806576  Skipped=0  Attempted=806576
# Inserted=808577  Skipped=0  Attempted=808577
# Inserted=810579  Skipped=0  Attempted=810579
# Inserted=812580  Skipped=0  Attempted=812580
# Inserted=814584  Skipped=0  Attempted=814584
# Inserted=816585  Skipped=0  Attempted=816585
# Inserted=818587  Skipped=0  Attempted=818587
# Inserted=820589  Skipped=0  Attempted=820589
# Inserted=822590  Skipped=0  Attempted=822590
# Inserted=824592  Skipped=0  Attempted=824592
# Inserted=826592  Skipped=0  Attempted=826592
# Inserted=828592  Skipped=0  Attempted=828592
# Inserted=830594  Skipped=0  Attempted=830594
# Inserted=832598  Skipped=0  Attempted=832598
# Inserted=834598  Skipped=0  Attempted=834598
# Inserted=836598  Skipped=0  Attempted=836598
# Inserted=838601  Skipped=0  Attempted=838601
# Inserted=840601  Skipped=0  Attempted=840601
# Inserted=842602  Skipped=0  Attempted=842602
# Inserted=844606  Skipped=0  Attempted=844606
# Inserted=846609  Skipped=0  Attempted=846609
# Inserted=848610  Skipped=0  Attempted=848610
# Inserted=850610  Skipped=0  Attempted=850610
# Inserted=852612  Skipped=0  Attempted=852612
# Inserted=854613  Skipped=0  Attempted=854613
# Inserted=856614  Skipped=0  Attempted=856614
# Inserted=858614  Skipped=0  Attempted=858614
# Inserted=860615  Skipped=0  Attempted=860615
# Inserted=862618  Skipped=0  Attempted=862618
# Inserted=864622  Skipped=0  Attempted=864622
# Inserted=866622  Skipped=0  Attempted=866622
# Inserted=868625  Skipped=0  Attempted=868625
# Inserted=870628  Skipped=0  Attempted=870628
# Inserted=872629  Skipped=0  Attempted=872629
# Inserted=874631  Skipped=0  Attempted=874631
# Inserted=876632  Skipped=0  Attempted=876632
# Inserted=878634  Skipped=0  Attempted=878634
# Inserted=880634  Skipped=0  Attempted=880634
# Inserted=882636  Skipped=0  Attempted=882636
# Inserted=884636  Skipped=0  Attempted=884636
# Inserted=886636  Skipped=0  Attempted=886636
# Inserted=888639  Skipped=0  Attempted=888639
# Inserted=890639  Skipped=0  Attempted=890639
# Inserted=892641  Skipped=0  Attempted=892641
# Inserted=894643  Skipped=0  Attempted=894643
# Inserted=896644  Skipped=0  Attempted=896644
# Inserted=898647  Skipped=0  Attempted=898647
# Inserted=900647  Skipped=0  Attempted=900647
# Inserted=902648  Skipped=0  Attempted=902648
# Inserted=904652  Skipped=0  Attempted=904652
# Inserted=906653  Skipped=0  Attempted=906653
# Inserted=908655  Skipped=0  Attempted=908655
# Inserted=910658  Skipped=0  Attempted=910658
# Inserted=912660  Skipped=0  Attempted=912660
# Inserted=914661  Skipped=0  Attempted=914661
# Inserted=916661  Skipped=0  Attempted=916661
# Inserted=918664  Skipped=0  Attempted=918664
# Inserted=920666  Skipped=0  Attempted=920666
# Inserted=922668  Skipped=0  Attempted=922668
# Inserted=924672  Skipped=0  Attempted=924672
# Inserted=926672  Skipped=0  Attempted=926672
# Inserted=928675  Skipped=0  Attempted=928675
# Inserted=930676  Skipped=0  Attempted=930676
# Inserted=932677  Skipped=0  Attempted=932677
# Inserted=934679  Skipped=0  Attempted=934679
# Inserted=936681  Skipped=0  Attempted=936681
# Inserted=938684  Skipped=0  Attempted=938684
# Inserted=940685  Skipped=0  Attempted=940685
# Inserted=942686  Skipped=0  Attempted=942686
# Inserted=944690  Skipped=0  Attempted=944690
# Inserted=946691  Skipped=0  Attempted=946691
# Inserted=948692  Skipped=0  Attempted=948692
# Inserted=950695  Skipped=0  Attempted=950695
# Inserted=952696  Skipped=0  Attempted=952696
# Inserted=954696  Skipped=0  Attempted=954696
# Inserted=956698  Skipped=0  Attempted=956698
# Inserted=958699  Skipped=0  Attempted=958699
# Inserted=960700  Skipped=0  Attempted=960700
# Inserted=962701  Skipped=0  Attempted=962701
# Inserted=964706  Skipped=0  Attempted=964706
# Inserted=966706  Skipped=0  Attempted=966706
# Inserted=968710  Skipped=0  Attempted=968710
# Inserted=970712  Skipped=0  Attempted=970712
# Inserted=972715  Skipped=0  Attempted=972715
# Inserted=974715  Skipped=0  Attempted=974715
# Inserted=976715  Skipped=0  Attempted=976715
# Inserted=978716  Skipped=0  Attempted=978716
# Inserted=980716  Skipped=0  Attempted=980716
# Inserted=982717  Skipped=0  Attempted=982717
# Inserted=984719  Skipped=0  Attempted=984719
# Inserted=986721  Skipped=0  Attempted=986721
# Inserted=988721  Skipped=0  Attempted=988721
# Inserted=990724  Skipped=0  Attempted=990724
# Inserted=992725  Skipped=0  Attempted=992725
# Inserted=994725  Skipped=0  Attempted=994725
# Inserted=996727  Skipped=0  Attempted=996727
# Inserted=998727  Skipped=0  Attempted=998727
# Inserted=1000728  Skipped=0  Attempted=1000728
# Inserted=1002731  Skipped=0  Attempted=1002731
# Inserted=1004733  Skipped=0  Attempted=1004733
# Inserted=1006733  Skipped=0  Attempted=1006733
# Inserted=1008734  Skipped=0  Attempted=1008734
# Inserted=1010735  Skipped=0  Attempted=1010735
# Inserted=1012738  Skipped=0  Attempted=1012738
# Inserted=1014739  Skipped=0  Attempted=1014739
# Inserted=1016742  Skipped=0  Attempted=1016742
# Inserted=1018745  Skipped=0  Attempted=1018745
# Inserted=1020748  Skipped=0  Attempted=1020748
# Inserted=1022749  Skipped=0  Attempted=1022749
# Inserted=1024750  Skipped=0  Attempted=1024750
# Inserted=1026751  Skipped=0  Attempted=1026751
# Inserted=1028754  Skipped=0  Attempted=1028754
# Inserted=1030755  Skipped=0  Attempted=1030755
# Inserted=1032757  Skipped=0  Attempted=1032757
# Inserted=1034757  Skipped=0  Attempted=1034757
# Inserted=1036758  Skipped=0  Attempted=1036758
# Inserted=1038759  Skipped=0  Attempted=1038759
# Inserted=1040759  Skipped=0  Attempted=1040759
# Inserted=1042760  Skipped=0  Attempted=1042760
# Inserted=1044762  Skipped=0  Attempted=1044762
# Inserted=1046763  Skipped=0  Attempted=1046763
# Inserted=1048765  Skipped=0  Attempted=1048765
# Inserted=1050766  Skipped=0  Attempted=1050766
# Inserted=1052769  Skipped=0  Attempted=1052769
# Inserted=1054770  Skipped=0  Attempted=1054770
# Inserted=1056773  Skipped=0  Attempted=1056773
# Inserted=1058777  Skipped=0  Attempted=1058777
# Inserted=1060779  Skipped=0  Attempted=1060779
# Inserted=1062780  Skipped=0  Attempted=1062780
# Inserted=1064780  Skipped=0  Attempted=1064780
# Inserted=1066780  Skipped=0  Attempted=1066780
# Inserted=1068780  Skipped=0  Attempted=1068780
# Inserted=1070780  Skipped=0  Attempted=1070780
# Inserted=1072784  Skipped=0  Attempted=1072784
# Inserted=1074784  Skipped=0  Attempted=1074784
# Inserted=1076784  Skipped=0  Attempted=1076784
# Inserted=1078788  Skipped=0  Attempted=1078788
# Inserted=1080790  Skipped=0  Attempted=1080790
# Inserted=1082790  Skipped=0  Attempted=1082790
# Inserted=1084795  Skipped=0  Attempted=1084795
# Inserted=1086795  Skipped=0  Attempted=1086795
# Inserted=1088795  Skipped=0  Attempted=1088795
# Inserted=1090796  Skipped=0  Attempted=1090796
# Inserted=1092798  Skipped=0  Attempted=1092798
# Inserted=1094801  Skipped=0  Attempted=1094801
# Inserted=1096805  Skipped=0  Attempted=1096805
# Inserted=1098806  Skipped=0  Attempted=1098806
# Inserted=1100806  Skipped=0  Attempted=1100806
# Inserted=1102807  Skipped=0  Attempted=1102807
# Inserted=1104807  Skipped=0  Attempted=1104807
# Inserted=1106808  Skipped=0  Attempted=1106808
# Inserted=1108811  Skipped=0  Attempted=1108811
# Inserted=1110811  Skipped=0  Attempted=1110811
# Inserted=1112812  Skipped=0  Attempted=1112812
# Inserted=1114816  Skipped=0  Attempted=1114816
# Inserted=1116816  Skipped=0  Attempted=1116816
# Inserted=1118816  Skipped=0  Attempted=1118816
# Inserted=1120816  Skipped=0  Attempted=1120816
# Inserted=1122817  Skipped=0  Attempted=1122817
# Inserted=1124818  Skipped=0  Attempted=1124818
# Inserted=1126818  Skipped=0  Attempted=1126818
# Inserted=1128818  Skipped=0  Attempted=1128818
# Inserted=1130821  Skipped=0  Attempted=1130821
# Inserted=1132821  Skipped=0  Attempted=1132821
# Inserted=1134822  Skipped=0  Attempted=1134822
# Inserted=1136822  Skipped=0  Attempted=1136822
# Inserted=1138822  Skipped=0  Attempted=1138822
# Inserted=1140825  Skipped=0  Attempted=1140825
# Inserted=1142827  Skipped=0  Attempted=1142827
# Inserted=1144829  Skipped=0  Attempted=1144829
# Inserted=1146833  Skipped=0  Attempted=1146833
# Inserted=1148834  Skipped=0  Attempted=1148834
# Inserted=1150837  Skipped=0  Attempted=1150837
# Inserted=1152839  Skipped=0  Attempted=1152839
# Inserted=1154842  Skipped=0  Attempted=1154842
# Inserted=1156844  Skipped=0  Attempted=1156844
# Inserted=1158844  Skipped=0  Attempted=1158844
# Inserted=1160845  Skipped=0  Attempted=1160845
# Inserted=1162845  Skipped=0  Attempted=1162845
# Inserted=1164848  Skipped=0  Attempted=1164848
# Inserted=1166850  Skipped=0  Attempted=1166850
# Inserted=1168851  Skipped=0  Attempted=1168851
# Inserted=1170852  Skipped=0  Attempted=1170852
# Inserted=1172853  Skipped=0  Attempted=1172853
# Inserted=1174853  Skipped=0  Attempted=1174853
# Inserted=1176856  Skipped=0  Attempted=1176856
# Inserted=1178857  Skipped=0  Attempted=1178857
# Inserted=1180860  Skipped=0  Attempted=1180860
# Inserted=1182860  Skipped=0  Attempted=1182860
# Inserted=1184862  Skipped=0  Attempted=1184862
# Inserted=1186863  Skipped=0  Attempted=1186863
# Inserted=1188865  Skipped=0  Attempted=1188865
# Inserted=1190865  Skipped=0  Attempted=1190865
# Inserted=1192865  Skipped=0  Attempted=1192865
# Inserted=1194865  Skipped=0  Attempted=1194865
# Inserted=1196866  Skipped=0  Attempted=1196866
# Inserted=1198866  Skipped=0  Attempted=1198866
# Inserted=1200868  Skipped=0  Attempted=1200868
# Inserted=1202872  Skipped=0  Attempted=1202872
# Inserted=1204872  Skipped=0  Attempted=1204872
# Inserted=1206873  Skipped=0  Attempted=1206873
# Inserted=1208876  Skipped=0  Attempted=1208876
# Inserted=1210879  Skipped=0  Attempted=1210879
# Inserted=1212879  Skipped=0  Attempted=1212879
# Inserted=1214879  Skipped=0  Attempted=1214879
# Inserted=1216880  Skipped=0  Attempted=1216880
# Inserted=1218882  Skipped=0  Attempted=1218882
# Inserted=1220886  Skipped=0  Attempted=1220886
# Inserted=1222894  Skipped=0  Attempted=1222894
# Inserted=1224895  Skipped=0  Attempted=1224895
# Inserted=1226896  Skipped=0  Attempted=1226896
# Inserted=1228896  Skipped=0  Attempted=1228896
# Inserted=1230899  Skipped=0  Attempted=1230899
# Inserted=1232902  Skipped=0  Attempted=1232902
# Inserted=1234903  Skipped=0  Attempted=1234903
# Inserted=1236904  Skipped=0  Attempted=1236904
# Inserted=1238907  Skipped=0  Attempted=1238907
# Inserted=1240911  Skipped=0  Attempted=1240911
# Inserted=1242913  Skipped=0  Attempted=1242913
# Inserted=1244917  Skipped=0  Attempted=1244917
# Inserted=1246919  Skipped=0  Attempted=1246919
# Inserted=1248922  Skipped=0  Attempted=1248922
# Inserted=1250922  Skipped=0  Attempted=1250922
# Inserted=1252927  Skipped=0  Attempted=1252927
# Inserted=1254929  Skipped=0  Attempted=1254929
# Inserted=1256930  Skipped=0  Attempted=1256930
# Inserted=1258931  Skipped=0  Attempted=1258931
# Inserted=1260931  Skipped=0  Attempted=1260931
# Inserted=1262931  Skipped=0  Attempted=1262931
# Inserted=1264933  Skipped=0  Attempted=1264933
# Inserted=1266933  Skipped=0  Attempted=1266933
# Inserted=1268934  Skipped=0  Attempted=1268934
# Inserted=1270937  Skipped=0  Attempted=1270937
# Inserted=1272937  Skipped=0  Attempted=1272937
# Inserted=1274940  Skipped=0  Attempted=1274940
# Inserted=1276943  Skipped=0  Attempted=1276943
# Inserted=1278943  Skipped=0  Attempted=1278943
# Inserted=1280944  Skipped=0  Attempted=1280944
# Inserted=1282944  Skipped=0  Attempted=1282944
# Inserted=1284947  Skipped=0  Attempted=1284947
# Inserted=1286947  Skipped=0  Attempted=1286947
# Inserted=1288947  Skipped=0  Attempted=1288947
# Inserted=1290949  Skipped=0  Attempted=1290949
# Inserted=1292951  Skipped=0  Attempted=1292951
# Inserted=1294951  Skipped=0  Attempted=1294951
# Inserted=1296953  Skipped=0  Attempted=1296953
# Inserted=1298954  Skipped=0  Attempted=1298954
# Inserted=1300954  Skipped=0  Attempted=1300954
# Inserted=1302954  Skipped=0  Attempted=1302954
# Inserted=1304954  Skipped=0  Attempted=1304954
# Inserted=1306957  Skipped=0  Attempted=1306957
# Inserted=1308959  Skipped=0  Attempted=1308959
# Inserted=1310959  Skipped=0  Attempted=1310959
# Inserted=1312959  Skipped=0  Attempted=1312959
# Inserted=1314961  Skipped=0  Attempted=1314961
# Inserted=1316964  Skipped=0  Attempted=1316964
# Inserted=1318966  Skipped=0  Attempted=1318966
# Inserted=1320968  Skipped=0  Attempted=1320968
# Inserted=1322988  Skipped=0  Attempted=1322988
# Inserted=1324992  Skipped=0  Attempted=1324992
# Inserted=1326992  Skipped=0  Attempted=1326992
# Inserted=1328993  Skipped=0  Attempted=1328993
# Inserted=1330995  Skipped=0  Attempted=1330995
# Inserted=1332998  Skipped=0  Attempted=1332998
# Inserted=1335000  Skipped=0  Attempted=1335000
# Inserted=1337003  Skipped=0  Attempted=1337003
# Inserted=1339004  Skipped=0  Attempted=1339004
# Inserted=1341004  Skipped=0  Attempted=1341004
# Inserted=1343006  Skipped=0  Attempted=1343006
# Inserted=1345010  Skipped=0  Attempted=1345010
# Inserted=1347011  Skipped=0  Attempted=1347011
# Inserted=1349011  Skipped=0  Attempted=1349011
# Inserted=1351015  Skipped=0  Attempted=1351015
# Inserted=1353015  Skipped=0  Attempted=1353015
# Inserted=1355016  Skipped=0  Attempted=1355016
# Inserted=1357017  Skipped=0  Attempted=1357017
# Inserted=1359019  Skipped=0  Attempted=1359019
# Inserted=1361019  Skipped=0  Attempted=1361019
# Inserted=1363023  Skipped=0  Attempted=1363023
# Inserted=1365027  Skipped=0  Attempted=1365027
# Inserted=1367030  Skipped=0  Attempted=1367030
# Inserted=1369031  Skipped=0  Attempted=1369031
# Inserted=1371032  Skipped=0  Attempted=1371032
# Inserted=1373036  Skipped=0  Attempted=1373036
# Inserted=1375036  Skipped=0  Attempted=1375036
# Inserted=1377039  Skipped=0  Attempted=1377039
# Inserted=1379039  Skipped=0  Attempted=1379039
# Inserted=1381040  Skipped=0  Attempted=1381040
# Inserted=1383042  Skipped=0  Attempted=1383042
# Inserted=1385044  Skipped=0  Attempted=1385044
# Inserted=1387049  Skipped=0  Attempted=1387049
# Inserted=1389049  Skipped=0  Attempted=1389049
# Inserted=1391053  Skipped=0  Attempted=1391053
# Inserted=1393054  Skipped=0  Attempted=1393054
# Inserted=1395054  Skipped=0  Attempted=1395054
# Inserted=1397055  Skipped=0  Attempted=1397055
# Inserted=1399057  Skipped=0  Attempted=1399057
# Inserted=1401058  Skipped=0  Attempted=1401058
# Inserted=1403058  Skipped=0  Attempted=1403058
# Inserted=1405060  Skipped=0  Attempted=1405060
# Inserted=1407061  Skipped=0  Attempted=1407061
# Inserted=1409063  Skipped=0  Attempted=1409063
# Inserted=1411064  Skipped=0  Attempted=1411064
# Inserted=1413065  Skipped=0  Attempted=1413065
# Inserted=1415069  Skipped=0  Attempted=1415069
# Inserted=1417069  Skipped=0  Attempted=1417069
# Inserted=1419070  Skipped=0  Attempted=1419070
# Inserted=1421072  Skipped=0  Attempted=1421072
# Inserted=1423073  Skipped=0  Attempted=1423073
# Inserted=1425073  Skipped=0  Attempted=1425073
# Inserted=1427074  Skipped=0  Attempted=1427074
# Inserted=1429075  Skipped=0  Attempted=1429075
# Inserted=1431076  Skipped=0  Attempted=1431076
# Inserted=1433078  Skipped=0  Attempted=1433078
# Inserted=1435078  Skipped=0  Attempted=1435078
# Inserted=1437079  Skipped=0  Attempted=1437079
# Inserted=1439081  Skipped=0  Attempted=1439081
# Inserted=1441082  Skipped=0  Attempted=1441082
# Inserted=1443083  Skipped=0  Attempted=1443083
# Inserted=1445083  Skipped=0  Attempted=1445083
# Inserted=1447084  Skipped=0  Attempted=1447084
# Inserted=1449084  Skipped=0  Attempted=1449084
# Inserted=1451087  Skipped=0  Attempted=1451087
# Inserted=1453093  Skipped=0  Attempted=1453093
# Inserted=1455095  Skipped=0  Attempted=1455095
# Inserted=1457095  Skipped=0  Attempted=1457095
# Inserted=1459098  Skipped=0  Attempted=1459098
# Inserted=1461098  Skipped=0  Attempted=1461098
# Inserted=1463101  Skipped=0  Attempted=1463101
# Inserted=1465101  Skipped=0  Attempted=1465101
# Inserted=1467103  Skipped=0  Attempted=1467103
# Inserted=1469105  Skipped=0  Attempted=1469105
# Inserted=1471105  Skipped=0  Attempted=1471105
# Inserted=1473106  Skipped=0  Attempted=1473106
# Inserted=1475106  Skipped=0  Attempted=1475106
# Inserted=1477109  Skipped=0  Attempted=1477109
# Inserted=1479109  Skipped=0  Attempted=1479109
# Inserted=1481112  Skipped=0  Attempted=1481112
# Inserted=1483115  Skipped=0  Attempted=1483115
# Inserted=1485115  Skipped=0  Attempted=1485115
# Inserted=1487117  Skipped=0  Attempted=1487117
# Inserted=1489117  Skipped=0  Attempted=1489117
# Inserted=1491119  Skipped=0  Attempted=1491119
# Inserted=1493122  Skipped=0  Attempted=1493122
# Inserted=1495127  Skipped=0  Attempted=1495127
# Inserted=1497129  Skipped=0  Attempted=1497129
# Inserted=1499129  Skipped=0  Attempted=1499129
# Inserted=1501133  Skipped=0  Attempted=1501133
# Inserted=1503133  Skipped=0  Attempted=1503133
# Inserted=1505135  Skipped=0  Attempted=1505135
# Inserted=1507139  Skipped=0  Attempted=1507139
# Inserted=1509142  Skipped=0  Attempted=1509142
# Inserted=1511143  Skipped=0  Attempted=1511143
# Inserted=1513144  Skipped=0  Attempted=1513144
# Inserted=1515144  Skipped=0  Attempted=1515144
# Inserted=1517147  Skipped=0  Attempted=1517147
# Inserted=1519151  Skipped=0  Attempted=1519151
# Inserted=1521151  Skipped=0  Attempted=1521151
# Inserted=1523151  Skipped=0  Attempted=1523151
# Inserted=1525152  Skipped=0  Attempted=1525152
# Inserted=1527152  Skipped=0  Attempted=1527152
# Inserted=1529152  Skipped=0  Attempted=1529152
# Inserted=1531153  Skipped=0  Attempted=1531153
# Inserted=1533153  Skipped=0  Attempted=1533153
# Inserted=1535153  Skipped=0  Attempted=1535153
# Inserted=1537155  Skipped=0  Attempted=1537155
# Inserted=1539156  Skipped=0  Attempted=1539156
# Inserted=1541158  Skipped=0  Attempted=1541158
# Inserted=1543161  Skipped=0  Attempted=1543161
# Inserted=1545161  Skipped=0  Attempted=1545161
# Inserted=1547163  Skipped=0  Attempted=1547163
# Inserted=1549165  Skipped=0  Attempted=1549165
# Inserted=1551165  Skipped=0  Attempted=1551165
# Inserted=1553165  Skipped=0  Attempted=1553165
# Inserted=1555165  Skipped=0  Attempted=1555165
# Inserted=1557166  Skipped=0  Attempted=1557166
# Inserted=1559169  Skipped=0  Attempted=1559169
# Inserted=1561170  Skipped=0  Attempted=1561170
# Inserted=1563172  Skipped=0  Attempted=1563172
# Inserted=1565175  Skipped=0  Attempted=1565175
# Inserted=1567175  Skipped=0  Attempted=1567175
# Inserted=1569175  Skipped=0  Attempted=1569175
# Inserted=1571175  Skipped=0  Attempted=1571175
# Inserted=1573177  Skipped=0  Attempted=1573177
# Inserted=1575177  Skipped=0  Attempted=1575177
# Inserted=1577178  Skipped=0  Attempted=1577178
# Inserted=1579180  Skipped=0  Attempted=1579180
# Inserted=1581181  Skipped=0  Attempted=1581181
# Inserted=1583183  Skipped=0  Attempted=1583183
# Inserted=1585183  Skipped=0  Attempted=1585183
# Inserted=1587183  Skipped=0  Attempted=1587183
# Inserted=1589184  Skipped=0  Attempted=1589184
# Inserted=1591184  Skipped=0  Attempted=1591184
# Inserted=1593186  Skipped=0  Attempted=1593186
# Inserted=1595188  Skipped=0  Attempted=1595188
# Inserted=1597190  Skipped=0  Attempted=1597190
# Inserted=1599190  Skipped=0  Attempted=1599190
# Inserted=1601194  Skipped=0  Attempted=1601194
# Inserted=1603194  Skipped=0  Attempted=1603194
# Inserted=1605194  Skipped=0  Attempted=1605194
# Inserted=1607195  Skipped=0  Attempted=1607195
# Inserted=1609198  Skipped=0  Attempted=1609198
# Inserted=1611202  Skipped=0  Attempted=1611202
# Inserted=1613206  Skipped=0  Attempted=1613206
# Inserted=1615206  Skipped=0  Attempted=1615206
# Inserted=1617209  Skipped=0  Attempted=1617209
# Inserted=1619213  Skipped=0  Attempted=1619213
# Inserted=1621213  Skipped=0  Attempted=1621213
# Inserted=1623215  Skipped=0  Attempted=1623215
# Inserted=1625216  Skipped=0  Attempted=1625216
# Inserted=1627216  Skipped=0  Attempted=1627216
# Inserted=1629218  Skipped=0  Attempted=1629218
# Inserted=1631218  Skipped=0  Attempted=1631218
# Inserted=1633222  Skipped=0  Attempted=1633222
# Inserted=1635222  Skipped=0  Attempted=1635222
# Inserted=1637222  Skipped=0  Attempted=1637222
# Inserted=1639223  Skipped=0  Attempted=1639223
# Inserted=1641223  Skipped=0  Attempted=1641223
# Inserted=1643226  Skipped=0  Attempted=1643226
# Inserted=1645228  Skipped=0  Attempted=1645228
# Inserted=1647230  Skipped=0  Attempted=1647230
# Inserted=1649230  Skipped=0  Attempted=1649230
# Inserted=1651231  Skipped=0  Attempted=1651231
# Inserted=1653235  Skipped=0  Attempted=1653235
# Inserted=1655236  Skipped=0  Attempted=1655236
# Inserted=1657236  Skipped=0  Attempted=1657236
# Inserted=1659238  Skipped=0  Attempted=1659238
# Inserted=1661239  Skipped=0  Attempted=1661239
# Inserted=1663240  Skipped=0  Attempted=1663240
# Inserted=1665241  Skipped=0  Attempted=1665241
# Inserted=1667252  Skipped=0  Attempted=1667252
# Inserted=1669252  Skipped=0  Attempted=1669252
# Inserted=1671253  Skipped=0  Attempted=1671253
# Inserted=1673256  Skipped=0  Attempted=1673256
# Inserted=1675257  Skipped=0  Attempted=1675257
# Inserted=1677261  Skipped=0  Attempted=1677261
# Inserted=1679265  Skipped=0  Attempted=1679265
# Inserted=1681266  Skipped=0  Attempted=1681266
# Inserted=1683270  Skipped=0  Attempted=1683270
# Inserted=1685271  Skipped=0  Attempted=1685271
# Inserted=1687272  Skipped=0  Attempted=1687272
# Inserted=1689276  Skipped=0  Attempted=1689276
# Inserted=1691279  Skipped=0  Attempted=1691279
# Inserted=1693280  Skipped=0  Attempted=1693280
# Inserted=1695282  Skipped=0  Attempted=1695282
# Inserted=1697283  Skipped=0  Attempted=1697283
# Inserted=1699287  Skipped=0  Attempted=1699287
# Inserted=1701290  Skipped=0  Attempted=1701290
# Inserted=1703292  Skipped=0  Attempted=1703292
# Inserted=1705292  Skipped=0  Attempted=1705292
# Inserted=1707292  Skipped=0  Attempted=1707292
# Inserted=1709296  Skipped=0  Attempted=1709296
# Inserted=1711300  Skipped=0  Attempted=1711300
# Inserted=1713301  Skipped=0  Attempted=1713301
# Inserted=1715301  Skipped=0  Attempted=1715301
# Inserted=1717303  Skipped=0  Attempted=1717303
# Inserted=1719307  Skipped=0  Attempted=1719307
# Inserted=1721309  Skipped=0  Attempted=1721309
# Inserted=1723311  Skipped=0  Attempted=1723311
# Inserted=1725314  Skipped=0  Attempted=1725314
# Inserted=1727315  Skipped=0  Attempted=1727315
# Inserted=1729316  Skipped=0  Attempted=1729316
# Inserted=1731318  Skipped=0  Attempted=1731318
# Inserted=1733318  Skipped=0  Attempted=1733318
# Inserted=1735318  Skipped=0  Attempted=1735318
# Inserted=1737318  Skipped=0  Attempted=1737318
# Inserted=1739319  Skipped=0  Attempted=1739319
# Inserted=1741320  Skipped=0  Attempted=1741320
# Inserted=1743323  Skipped=0  Attempted=1743323
# Inserted=1745323  Skipped=0  Attempted=1745323
# Inserted=1747324  Skipped=0  Attempted=1747324
# Inserted=1749326  Skipped=0  Attempted=1749326
# Inserted=1751328  Skipped=0  Attempted=1751328
# Inserted=1753330  Skipped=0  Attempted=1753330
# Inserted=1755332  Skipped=0  Attempted=1755332
# Inserted=1757336  Skipped=0  Attempted=1757336
# Inserted=1759336  Skipped=0  Attempted=1759336
# Inserted=1761336  Skipped=0  Attempted=1761336
# Inserted=1763337  Skipped=0  Attempted=1763337
# Inserted=1765337  Skipped=0  Attempted=1765337
# Inserted=1767338  Skipped=0  Attempted=1767338
# Inserted=1769339  Skipped=0  Attempted=1769339
# Inserted=1771340  Skipped=0  Attempted=1771340
# Inserted=1773340  Skipped=0  Attempted=1773340
# Inserted=1775341  Skipped=0  Attempted=1775341
# Inserted=1777344  Skipped=0  Attempted=1777344
# Inserted=1779345  Skipped=0  Attempted=1779345
# Inserted=1781347  Skipped=0  Attempted=1781347
# Inserted=1783351  Skipped=0  Attempted=1783351
# Inserted=1785351  Skipped=0  Attempted=1785351
# Inserted=1787351  Skipped=0  Attempted=1787351
# Inserted=1789352  Skipped=0  Attempted=1789352
# Inserted=1791352  Skipped=0  Attempted=1791352
# Inserted=1793352  Skipped=0  Attempted=1793352
# Inserted=1795356  Skipped=0  Attempted=1795356
# Inserted=1797356  Skipped=0  Attempted=1797356
# Inserted=1799356  Skipped=0  Attempted=1799356
# Inserted=1801356  Skipped=0  Attempted=1801356
# Inserted=1803358  Skipped=0  Attempted=1803358
# Inserted=1805361  Skipped=0  Attempted=1805361
# Inserted=1807362  Skipped=0  Attempted=1807362
# Inserted=1809363  Skipped=0  Attempted=1809363
# Inserted=1811363  Skipped=0  Attempted=1811363
# Inserted=1813371  Skipped=0  Attempted=1813371
# Inserted=1815373  Skipped=0  Attempted=1815373
# Inserted=1817375  Skipped=0  Attempted=1817375
# Inserted=1819378  Skipped=0  Attempted=1819378
# Inserted=1821381  Skipped=0  Attempted=1821381
# Inserted=1823384  Skipped=0  Attempted=1823384
# Inserted=1825387  Skipped=0  Attempted=1825387
# Inserted=1827389  Skipped=0  Attempted=1827389
# Inserted=1829389  Skipped=0  Attempted=1829389
# Inserted=1831389  Skipped=0  Attempted=1831389
# Inserted=1833392  Skipped=0  Attempted=1833392
# Inserted=1835393  Skipped=0  Attempted=1835393
# Inserted=1837395  Skipped=0  Attempted=1837395
# Inserted=1839395  Skipped=0  Attempted=1839395
# Inserted=1841395  Skipped=0  Attempted=1841395
# Inserted=1843395  Skipped=0  Attempted=1843395
# Inserted=1845398  Skipped=0  Attempted=1845398
# Inserted=1847398  Skipped=0  Attempted=1847398
# Inserted=1849400  Skipped=0  Attempted=1849400
# Inserted=1851402  Skipped=0  Attempted=1851402
# Inserted=1853402  Skipped=0  Attempted=1853402
# Inserted=1855405  Skipped=0  Attempted=1855405
# Inserted=1857406  Skipped=0  Attempted=1857406
# Inserted=1859406  Skipped=0  Attempted=1859406
# Inserted=1861406  Skipped=0  Attempted=1861406
# Inserted=1863407  Skipped=0  Attempted=1863407
# Inserted=1865410  Skipped=0  Attempted=1865410
# Inserted=1867411  Skipped=0  Attempted=1867411
# Inserted=1869415  Skipped=0  Attempted=1869415
# Inserted=1871415  Skipped=0  Attempted=1871415
# Inserted=1873416  Skipped=0  Attempted=1873416
# Inserted=1875419  Skipped=0  Attempted=1875419
# Inserted=1877420  Skipped=0  Attempted=1877420
# Inserted=1879422  Skipped=0  Attempted=1879422
# Inserted=1881425  Skipped=0  Attempted=1881425
# Inserted=1883426  Skipped=0  Attempted=1883426
# Inserted=1885427  Skipped=0  Attempted=1885427
# Inserted=1887427  Skipped=0  Attempted=1887427
# Inserted=1889428  Skipped=0  Attempted=1889428
# Inserted=1891428  Skipped=0  Attempted=1891428
# Inserted=1893429  Skipped=0  Attempted=1893429
# Inserted=1895431  Skipped=0  Attempted=1895431
# Inserted=1897433  Skipped=0  Attempted=1897433
# Inserted=1899435  Skipped=0  Attempted=1899435
# Inserted=1901437  Skipped=0  Attempted=1901437
# Inserted=1903439  Skipped=0  Attempted=1903439
# Inserted=1905439  Skipped=0  Attempted=1905439
# Inserted=1907440  Skipped=0  Attempted=1907440
# Inserted=1909443  Skipped=0  Attempted=1909443
# Inserted=1911449  Skipped=0  Attempted=1911449
# Inserted=1913449  Skipped=0  Attempted=1913449
# Inserted=1915453  Skipped=0  Attempted=1915453
# Inserted=1917456  Skipped=0  Attempted=1917456
# Inserted=1919458  Skipped=0  Attempted=1919458
# Inserted=1921462  Skipped=0  Attempted=1921462
# Inserted=1923465  Skipped=0  Attempted=1923465
# Inserted=1925468  Skipped=0  Attempted=1925468
# Inserted=1927468  Skipped=0  Attempted=1927468
# Inserted=1929468  Skipped=0  Attempted=1929468
# Inserted=1931468  Skipped=0  Attempted=1931468
# Inserted=1933472  Skipped=0  Attempted=1933472
# Inserted=1935476  Skipped=0  Attempted=1935476
# Inserted=1937479  Skipped=0  Attempted=1937479
# Inserted=1939483  Skipped=0  Attempted=1939483
# Inserted=1941484  Skipped=0  Attempted=1941484
# Inserted=1943484  Skipped=0  Attempted=1943484
# Inserted=1945486  Skipped=0  Attempted=1945486
# Inserted=1947486  Skipped=0  Attempted=1947486
# Inserted=1949486  Skipped=0  Attempted=1949486
# Inserted=1951487  Skipped=0  Attempted=1951487
# Inserted=1953487  Skipped=0  Attempted=1953487
# Inserted=1955490  Skipped=0  Attempted=1955490
# Inserted=1957490  Skipped=0  Attempted=1957490
# Inserted=1959491  Skipped=0  Attempted=1959491
# Inserted=1961491  Skipped=0  Attempted=1961491
# Inserted=1963494  Skipped=0  Attempted=1963494
# Inserted=1965497  Skipped=0  Attempted=1965497
# Inserted=1967500  Skipped=0  Attempted=1967500
# Inserted=1969504  Skipped=0  Attempted=1969504
# Inserted=1971506  Skipped=0  Attempted=1971506
# Inserted=1973508  Skipped=0  Attempted=1973508
# Inserted=1975508  Skipped=0  Attempted=1975508
# Inserted=1977509  Skipped=0  Attempted=1977509
# Inserted=1979509  Skipped=0  Attempted=1979509
# Inserted=1981510  Skipped=0  Attempted=1981510
# Inserted=1983513  Skipped=0  Attempted=1983513
# Inserted=1985513  Skipped=0  Attempted=1985513
# Inserted=1987516  Skipped=0  Attempted=1987516
# Inserted=1989518  Skipped=0  Attempted=1989518
# Inserted=1991521  Skipped=0  Attempted=1991521
# Inserted=1993522  Skipped=0  Attempted=1993522
# ...
# Inserted=2167644  Skipped=0  Attempted=2167644
# Inserted=2169647  Skipped=0  Attempted=2169647
# Inserted=2171649  Skipped=0  Attempted=2171649
# Inserted=2173650  Skipped=0  Attempted=2173650
# Inserted=2175650  Skipped=0  Attempted=2175650
# Inserted=2177651  Skipped=0  Attempted=2177651
# Inserted=2179655  Skipped=0  Attempted=2179655
# Inserted=2181658  Skipped=0  Attempted=2181658
# Inserted=2183660  Skipped=0  Attempted=2183660
# Inserted=2185660  Skipped=0  Attempted=2185660
# Inserted=2187660  Skipped=0  Attempted=2187660
# Inserted=2189660  Skipped=0  Attempted=2189660
# Inserted=2191661  Skipped=0  Attempted=2191661
# Inserted=2193661  Skipped=0  Attempted=2193661
# Inserted=2195664  Skipped=0  Attempted=2195664
# Inserted=2197667  Skipped=0  Attempted=2197667
# Inserted=2199667  Skipped=0  Attempted=2199667
# Inserted=2201667  Skipped=0  Attempted=2201667
# Inserted=2203669  Skipped=0  Attempted=2203669
# Inserted=2205671  Skipped=0  Attempted=2205671
# Inserted=2207672  Skipped=0  Attempted=2207672
# Inserted=2209673  Skipped=0  Attempted=2209673
# Inserted=2211678  Skipped=0  Attempted=2211678
# Inserted=2213679  Skipped=0  Attempted=2213679
# Inserted=2215683  Skipped=0  Attempted=2215683
# Inserted=2217684  Skipped=0  Attempted=2217684
# Inserted=2219684  Skipped=0  Attempted=2219684
# Inserted=2221684  Skipped=0  Attempted=2221684
# Inserted=2223687  Skipped=0  Attempted=2223687
# Inserted=2225690  Skipped=0  Attempted=2225690
# Inserted=2227693  Skipped=0  Attempted=2227693
# Inserted=2229693  Skipped=0  Attempted=2229693
# Inserted=2231693  Skipped=0  Attempted=2231693
# Inserted=2233695  Skipped=0  Attempted=2233695
# Inserted=2235696  Skipped=0  Attempted=2235696
# Inserted=2237700  Skipped=0  Attempted=2237700
# Inserted=2239702  Skipped=0  Attempted=2239702
# Inserted=2241704  Skipped=0  Attempted=2241704
# Inserted=2243707  Skipped=0  Attempted=2243707
# Inserted=2245708  Skipped=0  Attempted=2245708
# Inserted=2247711  Skipped=0  Attempted=2247711
# Inserted=2249711  Skipped=0  Attempted=2249711
# Inserted=2251711  Skipped=0  Attempted=2251711
# Inserted=2253711  Skipped=0  Attempted=2253711
# Inserted=2255711  Skipped=0  Attempted=2255711
# Inserted=2257713  Skipped=0  Attempted=2257713
# Inserted=2259715  Skipped=0  Attempted=2259715
# Inserted=2261715  Skipped=0  Attempted=2261715
# Inserted=2263715  Skipped=0  Attempted=2263715
# Inserted=2265718  Skipped=0  Attempted=2265718
# Inserted=2267720  Skipped=0  Attempted=2267720
# Inserted=2269721  Skipped=0  Attempted=2269721
# Inserted=2271723  Skipped=0  Attempted=2271723
# Inserted=2273725  Skipped=0  Attempted=2273725
# Inserted=2275726  Skipped=0  Attempted=2275726
# Inserted=2277728  Skipped=0  Attempted=2277728
# Inserted=2279731  Skipped=0  Attempted=2279731
# Inserted=2281731  Skipped=0  Attempted=2281731
# Inserted=2283734  Skipped=0  Attempted=2283734
# Inserted=2285737  Skipped=0  Attempted=2285737
# Inserted=2287737  Skipped=0  Attempted=2287737
# Inserted=2289738  Skipped=0  Attempted=2289738
# Inserted=2291741  Skipped=0  Attempted=2291741
# Inserted=2293741  Skipped=0  Attempted=2293741
# Inserted=2295743  Skipped=0  Attempted=2295743
# Inserted=2297743  Skipped=0  Attempted=2297743
# Inserted=2299744  Skipped=0  Attempted=2299744
# Inserted=2301746  Skipped=0  Attempted=2301746
# Inserted=2303746  Skipped=0  Attempted=2303746
# Inserted=2305746  Skipped=0  Attempted=2305746
# Inserted=2307747  Skipped=0  Attempted=2307747
# Inserted=2309748  Skipped=0  Attempted=2309748
# Inserted=2311752  Skipped=0  Attempted=2311752
# Inserted=2313752  Skipped=0  Attempted=2313752
# Inserted=2315754  Skipped=0  Attempted=2315754
# Inserted=2317754  Skipped=0  Attempted=2317754
# Inserted=2319754  Skipped=0  Attempted=2319754
# Inserted=2321755  Skipped=0  Attempted=2321755
# Inserted=2323758  Skipped=0  Attempted=2323758
# Inserted=2325761  Skipped=0  Attempted=2325761
# Inserted=2327762  Skipped=0  Attempted=2327762
# Inserted=2329763  Skipped=0  Attempted=2329763
# Inserted=2331763  Skipped=0  Attempted=2331763
# Inserted=2333763  Skipped=0  Attempted=2333763
# Inserted=2335764  Skipped=0  Attempted=2335764
# Inserted=2337765  Skipped=0  Attempted=2337765
# Inserted=2339768  Skipped=0  Attempted=2339768
# Inserted=2341768  Skipped=0  Attempted=2341768
# Inserted=2343770  Skipped=0  Attempted=2343770
# Inserted=2345770  Skipped=0  Attempted=2345770
# Inserted=2347771  Skipped=0  Attempted=2347771
# Inserted=2349771  Skipped=0  Attempted=2349771
# Inserted=2351773  Skipped=0  Attempted=2351773
# Inserted=2353776  Skipped=0  Attempted=2353776
# Inserted=2355776  Skipped=0  Attempted=2355776
# Inserted=2357778  Skipped=0  Attempted=2357778
# Inserted=2359782  Skipped=0  Attempted=2359782
# Inserted=2361784  Skipped=0  Attempted=2361784
# Inserted=2363784  Skipped=0  Attempted=2363784
# Inserted=2365787  Skipped=0  Attempted=2365787
# Inserted=2367788  Skipped=0  Attempted=2367788
# Inserted=2369791  Skipped=0  Attempted=2369791
# Inserted=2371791  Skipped=0  Attempted=2371791
# Inserted=2373792  Skipped=0  Attempted=2373792
# Inserted=2375793  Skipped=0  Attempted=2375793
# Inserted=2377795  Skipped=0  Attempted=2377795
# Inserted=2379795  Skipped=0  Attempted=2379795
# Inserted=2381798  Skipped=0  Attempted=2381798
# Inserted=2383798  Skipped=0  Attempted=2383798
# Inserted=2385798  Skipped=0  Attempted=2385798
# Inserted=2387799  Skipped=0  Attempted=2387799
# Inserted=2389802  Skipped=0  Attempted=2389802
# Inserted=2391803  Skipped=0  Attempted=2391803
# Inserted=2393803  Skipped=0  Attempted=2393803
# Inserted=2395803  Skipped=0  Attempted=2395803
# Inserted=2397805  Skipped=0  Attempted=2397805
# Inserted=2399805  Skipped=0  Attempted=2399805
# Inserted=2401809  Skipped=0  Attempted=2401809
# Inserted=2403812  Skipped=0  Attempted=2403812
# Inserted=2405813  Skipped=0  Attempted=2405813
# Inserted=2407815  Skipped=0  Attempted=2407815
# Inserted=2409817  Skipped=0  Attempted=2409817
# Inserted=2411817  Skipped=0  Attempted=2411817
# Inserted=2413820  Skipped=0  Attempted=2413820
# Inserted=2415822  Skipped=0  Attempted=2415822
# Inserted=2417822  Skipped=0  Attempted=2417822
# Inserted=2419822  Skipped=0  Attempted=2419822
# Inserted=2421824  Skipped=0  Attempted=2421824
# Inserted=2423826  Skipped=0  Attempted=2423826
# Inserted=2425826  Skipped=0  Attempted=2425826
# Inserted=2427829  Skipped=0  Attempted=2427829
# Inserted=2429830  Skipped=0  Attempted=2429830
# Inserted=2431831  Skipped=0  Attempted=2431831
# Inserted=2433831  Skipped=0  Attempted=2433831
# Inserted=2435835  Skipped=0  Attempted=2435835
# Inserted=2437835  Skipped=0  Attempted=2437835
# Inserted=2439835  Skipped=0  Attempted=2439835
# Inserted=2441837  Skipped=0  Attempted=2441837
# Inserted=2443837  Skipped=0  Attempted=2443837
# Inserted=2445840  Skipped=0  Attempted=2445840
# Inserted=2447843  Skipped=0  Attempted=2447843
# Inserted=2449843  Skipped=0  Attempted=2449843
# Inserted=2451845  Skipped=0  Attempted=2451845
# Inserted=2453845  Skipped=0  Attempted=2453845
# Inserted=2455845  Skipped=0  Attempted=2455845
# Inserted=2457846  Skipped=0  Attempted=2457846
# Inserted=2459848  Skipped=0  Attempted=2459848
# Inserted=2461851  Skipped=0  Attempted=2461851
# Inserted=2463854  Skipped=0  Attempted=2463854
# Inserted=2465856  Skipped=0  Attempted=2465856
# Inserted=2467858  Skipped=0  Attempted=2467858
# Inserted=2469859  Skipped=0  Attempted=2469859
# Inserted=2471859  Skipped=0  Attempted=2471859
# Inserted=2473863  Skipped=0  Attempted=2473863
# Inserted=2475867  Skipped=0  Attempted=2475867
# Inserted=2477867  Skipped=0  Attempted=2477867
# Inserted=2479870  Skipped=0  Attempted=2479870
# Inserted=2481872  Skipped=0  Attempted=2481872
# Inserted=2483874  Skipped=0  Attempted=2483874
# Inserted=2485874  Skipped=0  Attempted=2485874
# Inserted=2487876  Skipped=0  Attempted=2487876
# Inserted=2489876  Skipped=0  Attempted=2489876
# Inserted=2491881  Skipped=0  Attempted=2491881
# Inserted=2493883  Skipped=0  Attempted=2493883
# Inserted=2495885  Skipped=0  Attempted=2495885
# Inserted=2497889  Skipped=0  Attempted=2497889
# Inserted=2499889  Skipped=0  Attempted=2499889
# Inserted=2501889  Skipped=0  Attempted=2501889
# Inserted=2503891  Skipped=0  Attempted=2503891
# Inserted=2505894  Skipped=0  Attempted=2505894
# Inserted=2507894  Skipped=0  Attempted=2507894
# Inserted=2509895  Skipped=0  Attempted=2509895
# Inserted=2511895  Skipped=0  Attempted=2511895
# Inserted=2513896  Skipped=0  Attempted=2513896
# Inserted=2515896  Skipped=0  Attempted=2515896
# Inserted=2517898  Skipped=0  Attempted=2517898
# Inserted=2519901  Skipped=0  Attempted=2519901
# Inserted=2521904  Skipped=0  Attempted=2521904
# Inserted=2523904  Skipped=0  Attempted=2523904
# Inserted=2525907  Skipped=0  Attempted=2525907
# Inserted=2527907  Skipped=0  Attempted=2527907
# Inserted=2529909  Skipped=0  Attempted=2529909
# Inserted=2531909  Skipped=0  Attempted=2531909
# Inserted=2533909  Skipped=0  Attempted=2533909
# Inserted=2535913  Skipped=0  Attempted=2535913
# Inserted=2537913  Skipped=0  Attempted=2537913
# Inserted=2539915  Skipped=0  Attempted=2539915
# Inserted=2541916  Skipped=0  Attempted=2541916
# Inserted=2543916  Skipped=0  Attempted=2543916
# Inserted=2545917  Skipped=0  Attempted=2545917
# Inserted=2547917  Skipped=0  Attempted=2547917
# Inserted=2549919  Skipped=0  Attempted=2549919
# Inserted=2551919  Skipped=0  Attempted=2551919
# Inserted=2553919  Skipped=0  Attempted=2553919
# Inserted=2555919  Skipped=0  Attempted=2555919
# Inserted=2557920  Skipped=0  Attempted=2557920
# Inserted=2559922  Skipped=0  Attempted=2559922
# Inserted=2561922  Skipped=0  Attempted=2561922
# Inserted=2563923  Skipped=0  Attempted=2563923
# Inserted=2565923  Skipped=0  Attempted=2565923
# Inserted=2567924  Skipped=0  Attempted=2567924
# Inserted=2569929  Skipped=0  Attempted=2569929
# Inserted=2571932  Skipped=0  Attempted=2571932
# Inserted=2573935  Skipped=0  Attempted=2573935
# Inserted=2575937  Skipped=0  Attempted=2575937
# Inserted=2577940  Skipped=0  Attempted=2577940
# Inserted=2579940  Skipped=0  Attempted=2579940
# Inserted=2581940  Skipped=0  Attempted=2581940
# Inserted=2583942  Skipped=0  Attempted=2583942
# Inserted=2585944  Skipped=0  Attempted=2585944
# Inserted=2587983  Skipped=0  Attempted=2587983
# Inserted=2589985  Skipped=0  Attempted=2589985
# Inserted=2591987  Skipped=0  Attempted=2591987
# Inserted=2593988  Skipped=0  Attempted=2593988
# Inserted=2595992  Skipped=0  Attempted=2595992
# Inserted=2597995  Skipped=0  Attempted=2597995
# Inserted=2599999  Skipped=0  Attempted=2599999
# Inserted=2601999  Skipped=0  Attempted=2601999
# Inserted=2603999  Skipped=0  Attempted=2603999
# Inserted=2606000  Skipped=0  Attempted=2606000
# Inserted=2608001  Skipped=0  Attempted=2608001
# Inserted=2610001  Skipped=0  Attempted=2610001
# Inserted=2612001  Skipped=0  Attempted=2612001
# Inserted=2614003  Skipped=0  Attempted=2614003
# Inserted=2616006  Skipped=0  Attempted=2616006
# Inserted=2618006  Skipped=0  Attempted=2618006
# Inserted=2620007  Skipped=0  Attempted=2620007
# Inserted=2622007  Skipped=0  Attempted=2622007
# Inserted=2624009  Skipped=0  Attempted=2624009
# Inserted=2626009  Skipped=0  Attempted=2626009
# Inserted=2628010  Skipped=0  Attempted=2628010
# Inserted=2630012  Skipped=0  Attempted=2630012
# Inserted=2632012  Skipped=0  Attempted=2632012
# Inserted=2634012  Skipped=0  Attempted=2634012
# Inserted=2636012  Skipped=0  Attempted=2636012
# Inserted=2638013  Skipped=0  Attempted=2638013
# Inserted=2640013  Skipped=0  Attempted=2640013
# Inserted=2642013  Skipped=0  Attempted=2642013
# Inserted=2644017  Skipped=0  Attempted=2644017
# Inserted=2646017  Skipped=0  Attempted=2646017
# Inserted=2648018  Skipped=0  Attempted=2648018
# Inserted=2650019  Skipped=0  Attempted=2650019
# Inserted=2652022  Skipped=0  Attempted=2652022
# Inserted=2654022  Skipped=0  Attempted=2654022
# Inserted=2656022  Skipped=0  Attempted=2656022
# Inserted=2658023  Skipped=0  Attempted=2658023
# Inserted=2660026  Skipped=0  Attempted=2660026
# Inserted=2662027  Skipped=0  Attempted=2662027
# Inserted=2664030  Skipped=0  Attempted=2664030
# Inserted=2666031  Skipped=0  Attempted=2666031
# Inserted=2668033  Skipped=0  Attempted=2668033
# Inserted=2670035  Skipped=0  Attempted=2670035
# Inserted=2672036  Skipped=0  Attempted=2672036
# Inserted=2674036  Skipped=0  Attempted=2674036
# Inserted=2676038  Skipped=0  Attempted=2676038
# Inserted=2678040  Skipped=0  Attempted=2678040
# Inserted=2680044  Skipped=0  Attempted=2680044
# Inserted=2682048  Skipped=0  Attempted=2682048
# Inserted=2684050  Skipped=0  Attempted=2684050
# Inserted=2686050  Skipped=0  Attempted=2686050
# Inserted=2688053  Skipped=0  Attempted=2688053
# Inserted=2690054  Skipped=0  Attempted=2690054
# Inserted=2692054  Skipped=0  Attempted=2692054
# Inserted=2694057  Skipped=0  Attempted=2694057
# Inserted=2696057  Skipped=0  Attempted=2696057
# Inserted=2698057  Skipped=0  Attempted=2698057
# Inserted=2700057  Skipped=0  Attempted=2700057
# Inserted=2702060  Skipped=0  Attempted=2702060
# Inserted=2704060  Skipped=0  Attempted=2704060
# Inserted=2706060  Skipped=0  Attempted=2706060
# Inserted=2708062  Skipped=0  Attempted=2708062
# Inserted=2710066  Skipped=0  Attempted=2710066
# Inserted=2712066  Skipped=0  Attempted=2712066
# Inserted=2714066  Skipped=0  Attempted=2714066
# Inserted=2716066  Skipped=0  Attempted=2716066
# Inserted=2718068  Skipped=0  Attempted=2718068
# Inserted=2720070  Skipped=0  Attempted=2720070
# Inserted=2722070  Skipped=0  Attempted=2722070
# Inserted=2724070  Skipped=0  Attempted=2724070
# Inserted=2726073  Skipped=0  Attempted=2726073
# Inserted=2728077  Skipped=0  Attempted=2728077
# Inserted=2730077  Skipped=0  Attempted=2730077
# Inserted=2732081  Skipped=0  Attempted=2732081
# Inserted=2734083  Skipped=0  Attempted=2734083
# Inserted=2736087  Skipped=0  Attempted=2736087
# Inserted=2738091  Skipped=0  Attempted=2738091
# Inserted=2740091  Skipped=0  Attempted=2740091
# Inserted=2742091  Skipped=0  Attempted=2742091
# Inserted=2744094  Skipped=0  Attempted=2744094
# Inserted=2746095  Skipped=0  Attempted=2746095
# Inserted=2748095  Skipped=0  Attempted=2748095
# Inserted=2750102  Skipped=0  Attempted=2750102
# Inserted=2752102  Skipped=0  Attempted=2752102
# Inserted=2754102  Skipped=0  Attempted=2754102
# Inserted=2756102  Skipped=0  Attempted=2756102
# Inserted=2758103  Skipped=0  Attempted=2758103
# Inserted=2760107  Skipped=0  Attempted=2760107
# Inserted=2762108  Skipped=0  Attempted=2762108
# Inserted=2764108  Skipped=0  Attempted=2764108
# Inserted=2766109  Skipped=0  Attempted=2766109
# Inserted=2768112  Skipped=0  Attempted=2768112
# Inserted=2770113  Skipped=0  Attempted=2770113
# Inserted=2772114  Skipped=0  Attempted=2772114
# Inserted=2774116  Skipped=0  Attempted=2774116
# Inserted=2776118  Skipped=0  Attempted=2776118
# Inserted=2778118  Skipped=0  Attempted=2778118
# Inserted=2780120  Skipped=0  Attempted=2780120
# Inserted=2782120  Skipped=0  Attempted=2782120
# Inserted=2784122  Skipped=0  Attempted=2784122
# Inserted=2786122  Skipped=0  Attempted=2786122
# Inserted=2788124  Skipped=0  Attempted=2788124
# Inserted=2790125  Skipped=0  Attempted=2790125
# Inserted=2792125  Skipped=0  Attempted=2792125
# Inserted=2794128  Skipped=0  Attempted=2794128
# Inserted=2796128  Skipped=0  Attempted=2796128
# Inserted=2798128  Skipped=0  Attempted=2798128
# Inserted=2800132  Skipped=0  Attempted=2800132
# Inserted=2802134  Skipped=0  Attempted=2802134
# Inserted=2804134  Skipped=0  Attempted=2804134
# Inserted=2806136  Skipped=0  Attempted=2806136
# Inserted=2808138  Skipped=0  Attempted=2808138
# Inserted=2810140  Skipped=0  Attempted=2810140
# Inserted=2812142  Skipped=0  Attempted=2812142
# Inserted=2814144  Skipped=0  Attempted=2814144
# Inserted=2816144  Skipped=0  Attempted=2816144
# Inserted=2818146  Skipped=0  Attempted=2818146
# Inserted=2820148  Skipped=0  Attempted=2820148
# Inserted=2822148  Skipped=0  Attempted=2822148
# Inserted=2824152  Skipped=0  Attempted=2824152
# Inserted=2826155  Skipped=0  Attempted=2826155
# Inserted=2828158  Skipped=0  Attempted=2828158
# Inserted=2830160  Skipped=0  Attempted=2830160
# Inserted=2832163  Skipped=0  Attempted=2832163
# Inserted=2834163  Skipped=0  Attempted=2834163
# Inserted=2836163  Skipped=0  Attempted=2836163
# Inserted=2838164  Skipped=0  Attempted=2838164
# Inserted=2838947  Skipped=0  Attempted=2838947
#
# Done.
# Row groups       : 1
# Rows seen        : 936428
# Chunks seen      : 2838947
# Attempted chunks : 2838947
# Inserted chunks  : 2838947
# Skipped existing : 0
