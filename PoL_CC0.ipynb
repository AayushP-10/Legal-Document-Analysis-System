# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.42.73-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.43.0,>=1.42.73 (from boto3)
#   Downloading botocore-1.42.73-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.73->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.73->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.73->boto3) (1.17.0)
# Downloading boto3-1.42.73-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 11.4 MB/s eta 0:00:00
# Downloading botocore-1.42.73-py3-none-any.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 133.2 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.73 botocore-1.42.73 jmespath-1.1.0 s3transfer-0.16.0

# %%
import os
import hashlib
from typing import List, Dict, Iterable

import boto3
import pyarrow.parquet as pq
from botocore.config import Config
from botocore.exceptions import ClientError
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer
from google.colab import userdata


# ================= CONFIG =================
AWS_ACCESS_KEY_ID = userdata.get("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = userdata.get("AWS_SECRET_ACCESS_KEY")
AWS_REGION = userdata.get("AWS_DEFAULT_REGION") or "us-east-2"

SOURCE_BUCKET = "cleaned-legal-data-analysis-src-v2"
PARQUET_KEY = "pile_of_law/cleaned_contracts_2.parquet"

TARGET_VECTOR_BUCKET = "combined.embeddings"
TARGET_INDEX_NAME = "legal-combined-index"

MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"

MAX_TOKENS = 350
OVERLAP = 75

EMBED_BATCH = 512
BUFFER_SIZE = 2000
PUT_BATCH = 100
GET_EXISTING_BATCH = 100

LOCAL_PARQUET_PATH = "/tmp/pile_of_law_current.parquet"


# ================= AWS SESSION =================
session = boto3.Session(
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    region_name=AWS_REGION,
)

cfg = Config(retries={"max_attempts": 10, "mode": "standard"})
s3 = session.client("s3", config=cfg)
vec = session.client("s3vectors", config=cfg)


# ================= MODEL =================
print("Loading model on GPU...")
model = SentenceTransformer(MODEL_NAME, device="cuda")
model = model.half()
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)


# ================= HELPERS =================
def clean_text(x) -> str:
    return " ".join(str(x).replace("\x00", " ").split()).strip()


def chunk_text(text: str) -> List[str]:
    text = clean_text(text)
    if not text:
        return []

    token_ids = tokenizer(
        text,
        add_special_tokens=False,
        truncation=False,
        return_attention_mask=False,
        return_token_type_ids=False,
    )["input_ids"]

    if not token_ids:
        return []

    if len(token_ids) <= MAX_TOKENS:
        chunk = tokenizer.decode(token_ids, skip_special_tokens=True).strip()
        return [chunk] if chunk else []

    chunks = []
    step = MAX_TOKENS - OVERLAP

    for start in range(0, len(token_ids), step):
        end = start + MAX_TOKENS
        piece = token_ids[start:end]
        if not piece:
            continue

        chunk = tokenizer.decode(piece, skip_special_tokens=True).strip()
        if chunk:
            chunks.append(chunk)

        if end >= len(token_ids):
            break

    return chunks


def make_vector_key(
    dataset: str,
    parquet_key: str,
    row_group_idx: int,
    row_idx: int,
    chunk_idx: int,
    doc_id: str,
    chunk_text_value: str,
) -> str:
    base = f"{dataset}|{parquet_key}|rg={row_group_idx}|row={row_idx}|chunk={chunk_idx}|doc={doc_id}"
    base_hash = hashlib.md5(base.encode("utf-8")).hexdigest()[:20]
    text_hash = hashlib.md5(chunk_text_value.encode("utf-8")).hexdigest()[:12]
    return f"{dataset}::{base_hash}::{text_hash}"


def batched(items: List, size: int) -> Iterable[List]:
    for i in range(0, len(items), size):
        yield items[i:i + size]


def ensure_vector_bucket_and_index() -> None:
    bucket_exists = True
    try:
        vec.get_vector_bucket(vectorBucketName=TARGET_VECTOR_BUCKET)
    except ClientError as e:
        code = e.response.get("Error", {}).get("Code", "")
        if code in {"NotFoundException", "ResourceNotFoundException"}:
            bucket_exists = False
        else:
            raise

    if not bucket_exists:
        vec.create_vector_bucket(vectorBucketName=TARGET_VECTOR_BUCKET)

    index_exists = True
    try:
        vec.get_index(
            vectorBucketName=TARGET_VECTOR_BUCKET,
            indexName=TARGET_INDEX_NAME,
        )
    except ClientError as e:
        code = e.response.get("Error", {}).get("Code", "")
        if code in {"NotFoundException", "ResourceNotFoundException"}:
            index_exists = False
        else:
            raise

    if not index_exists:
        vec.create_index(
            vectorBucketName=TARGET_VECTOR_BUCKET,
            indexName=TARGET_INDEX_NAME,
            dataType="float32",
            dimension=384,
            distanceMetric="cosine",
        )


def existing_keys(keys: List[str]) -> set:
    found = set()

    for batch in batched(keys, GET_EXISTING_BATCH):
        try:
            resp = vec.get_vectors(
                vectorBucketName=TARGET_VECTOR_BUCKET,
                indexName=TARGET_INDEX_NAME,
                keys=batch,
            )
            for item in resp.get("vectors", []):
                k = item.get("key")
                if k:
                    found.add(k)
        except ClientError:
            pass

    return found


def put_vectors(vectors: List[Dict]) -> None:
    for batch in batched(vectors, PUT_BATCH):
        vec.put_vectors(
            vectorBucketName=TARGET_VECTOR_BUCKET,
            indexName=TARGET_INDEX_NAME,
            vectors=batch,
        )


def flush_buffer(buffer: List[Dict], stats: Dict[str, int]) -> List[Dict]:
    if not buffer:
        return []

    unique_map = {}
    for row in buffer:
        unique_map[row["key"]] = row
    unique_rows = list(unique_map.values())

    stats["attempted"] += len(unique_rows)

    keys = [row["key"] for row in unique_rows]
    already = existing_keys(keys)

    to_insert = [row for row in unique_rows if row["key"] not in already]
    skipped = len(unique_rows) - len(to_insert)
    stats["skipped"] += skipped

    if not to_insert:
        print(
            f"Inserted={stats['inserted']}  "
            f"Skipped={stats['skipped']}  "
            f"Attempted={stats['attempted']}"
        )
        return []

    texts = [row["text"] for row in to_insert]
    embeddings = model.encode(
        texts,
        batch_size=EMBED_BATCH,
        normalize_embeddings=True,
        show_progress_bar=False,
    )

    payload = []
    seen_payload = set()

    for row, emb in zip(to_insert, embeddings):
        key = row["key"]
        if key in seen_payload:
            continue
        seen_payload.add(key)

        payload.append(
            {
                "key": key,
                "data": {"float32": [float(x) for x in emb]},
                "metadata": {
                    "dataset": "pile_of_law",
                    "doc_id": row["doc_id"][:200],
                    "source_uri": row["source_uri"][:500],
                },
            }
        )

    if payload:
        put_vectors(payload)
        stats["inserted"] += len(payload)

    print(
        f"Inserted={stats['inserted']}  "
        f"Skipped={stats['skipped']}  "
        f"Attempted={stats['attempted']}"
    )
    return []


# ================= MAIN =================
def main():
    if not AWS_ACCESS_KEY_ID or not AWS_SECRET_ACCESS_KEY:
        raise ValueError("AWS credentials not found in Colab secrets.")

    print("Ensuring target vector bucket and index exist...")
    ensure_vector_bucket_and_index()

    print(f"Downloading parquet from s3://{SOURCE_BUCKET}/{PARQUET_KEY}")
    s3.download_file(SOURCE_BUCKET, PARQUET_KEY, LOCAL_PARQUET_PATH)
    print(f"Local file ready: {LOCAL_PARQUET_PATH}")

    parquet_file = pq.ParquetFile(LOCAL_PARQUET_PATH)

    stats = {
        "row_groups": parquet_file.num_row_groups,
        "rows_seen": 0,
        "chunks_seen": 0,
        "attempted": 0,
        "inserted": 0,
        "skipped": 0,
    }

    buffer = []
    source_uri = f"s3://{SOURCE_BUCKET}/{PARQUET_KEY}"

    print("Processing parquet row groups...")
    for rg_idx in range(parquet_file.num_row_groups):
        table = parquet_file.read_row_group(rg_idx)
        rows = table.to_pylist()

        for row_idx, row in enumerate(rows):
            stats["rows_seen"] += 1

            text = clean_text(
                row.get("text")
                or row.get("cleaned_text")
                or row.get("content")
                or row.get("body")
                or ""
            )
            if not text:
                continue

            doc_id = clean_text(
                row.get("doc_id")
                or row.get("document_id")
                or row.get("contract_id")
                or row.get("file_id")
                or row.get("id")
                or f"doc_{rg_idx}_{row_idx}"
            )

            chunks = chunk_text(text)
            if not chunks:
                continue

            for chunk_idx, chunk_value in enumerate(chunks):
                stats["chunks_seen"] += 1
                key = make_vector_key(
                    dataset="pile_of_law",
                    parquet_key=PARQUET_KEY,
                    row_group_idx=rg_idx,
                    row_idx=row_idx,
                    chunk_idx=chunk_idx,
                    doc_id=doc_id,
                    chunk_text_value=chunk_value,
                )

                buffer.append(
                    {
                        "key": key,
                        "doc_id": doc_id,
                        "text": chunk_value,
                        "source_uri": source_uri,
                    }
                )

            if len(buffer) >= BUFFER_SIZE:
                buffer = flush_buffer(buffer, stats)

    if buffer:
        buffer = flush_buffer(buffer, stats)

    print("\nDone.")
    print(f"Row groups       : {stats['row_groups']}")
    print(f"Rows seen        : {stats['rows_seen']}")
    print(f"Chunks seen      : {stats['chunks_seen']}")
    print(f"Attempted chunks : {stats['attempted']}")
    print(f"Inserted chunks  : {stats['inserted']}")
    print(f"Skipped existing : {stats['skipped']}")


if __name__ == "__main__":
    main()
# Out:
# Loading model on GPU...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Ensuring target vector bucket and index exist...
# Downloading parquet from s3://cleaned-legal-data-analysis-src-v2/pile_of_law/cleaned_contracts_2.parquet
# Local file ready: /tmp/pile_of_law_current.parquet
# Processing parquet row groups...
# Token indices sequence length is longer than the specified maximum sequence length for this model (919 > 512). Running this sequence through the model will result in indexing errors
# Inserted=0  Skipped=2000  Attempted=2000
# Inserted=0  Skipped=4000  Attempted=4000
# Inserted=0  Skipped=6004  Attempted=6004
# Inserted=0  Skipped=8005  Attempted=8005
# Inserted=0  Skipped=10008  Attempted=10008
# Inserted=0  Skipped=12008  Attempted=12008
# Inserted=0  Skipped=14008  Attempted=14008
# Inserted=0  Skipped=16011  Attempted=16011
# Inserted=0  Skipped=18013  Attempted=18013
# Inserted=0  Skipped=20014  Attempted=20014
# Inserted=0  Skipped=22020  Attempted=22020
# Inserted=0  Skipped=24024  Attempted=24024
# Inserted=0  Skipped=26025  Attempted=26025
# Inserted=0  Skipped=28025  Attempted=28025
# Inserted=0  Skipped=30026  Attempted=30026
# Inserted=0  Skipped=32027  Attempted=32027
# Inserted=0  Skipped=34029  Attempted=34029
# Inserted=0  Skipped=36032  Attempted=36032
# Inserted=0  Skipped=38032  Attempted=38032
# Inserted=0  Skipped=40032  Attempted=40032
# Inserted=0  Skipped=42033  Attempted=42033
# Inserted=0  Skipped=44037  Attempted=44037
# Inserted=0  Skipped=46037  Attempted=46037
# Inserted=0  Skipped=48037  Attempted=48037
# Inserted=0  Skipped=50038  Attempted=50038
# Inserted=0  Skipped=52041  Attempted=52041
# Inserted=0  Skipped=54041  Attempted=54041
# Inserted=0  Skipped=56043  Attempted=56043
# Inserted=0  Skipped=58044  Attempted=58044
# Inserted=0  Skipped=60046  Attempted=60046
# Inserted=0  Skipped=62047  Attempted=62047
# Inserted=0  Skipped=64048  Attempted=64048
# Inserted=0  Skipped=66048  Attempted=66048
# Inserted=0  Skipped=68049  Attempted=68049
# Inserted=0  Skipped=70052  Attempted=70052
# Inserted=0  Skipped=72053  Attempted=72053
# Inserted=0  Skipped=74056  Attempted=74056
# Inserted=0  Skipped=76056  Attempted=76056
# Inserted=0  Skipped=78057  Attempted=78057
# Inserted=0  Skipped=80061  Attempted=80061
# Inserted=0  Skipped=82062  Attempted=82062
# Inserted=0  Skipped=84063  Attempted=84063
# Inserted=0  Skipped=86065  Attempted=86065
# Inserted=0  Skipped=88065  Attempted=88065
# Inserted=0  Skipped=90067  Attempted=90067
# Inserted=0  Skipped=92067  Attempted=92067
# Inserted=0  Skipped=94068  Attempted=94068
# Inserted=0  Skipped=96071  Attempted=96071
# Inserted=0  Skipped=98072  Attempted=98072
# Inserted=0  Skipped=100072  Attempted=100072
# Inserted=0  Skipped=102072  Attempted=102072
# Inserted=0  Skipped=104073  Attempted=104073
# Inserted=0  Skipped=106073  Attempted=106073
# Inserted=0  Skipped=108073  Attempted=108073
# Inserted=0  Skipped=110073  Attempted=110073
# Inserted=0  Skipped=112073  Attempted=112073
# Inserted=0  Skipped=114075  Attempted=114075
# Inserted=0  Skipped=116078  Attempted=116078
# Inserted=0  Skipped=118079  Attempted=118079
# Inserted=0  Skipped=120082  Attempted=120082
# Inserted=0  Skipped=122082  Attempted=122082
# Inserted=0  Skipped=124086  Attempted=124086
# Inserted=0  Skipped=126089  Attempted=126089
# Inserted=0  Skipped=128092  Attempted=128092
# Inserted=0  Skipped=130095  Attempted=130095
# Inserted=0  Skipped=132097  Attempted=132097
# Inserted=0  Skipped=134098  Attempted=134098
# Inserted=324271  Skipped=934764  Attempted=1259035
# Inserted=326272  Skipped=934764  Attempted=1261036
# Inserted=328273  Skipped=934764  Attempted=1263037
# Inserted=330276  Skipped=934764  Attempted=1265040
# Inserted=332277  Skipped=934764  Attempted=1267041
# Inserted=334277  Skipped=934764  Attempted=1269041
# Inserted=336278  Skipped=934764  Attempted=1271042
# Inserted=338280  Skipped=934764  Attempted=1273044
# Inserted=340283  Skipped=934764  Attempted=1275047
# Inserted=342284  Skipped=934764  Attempted=1277048
# Inserted=344286  Skipped=934764  Attempted=1279050
# Inserted=346287  Skipped=934764  Attempted=1281051
# Inserted=348289  Skipped=934764  Attempted=1283053
# Inserted=350292  Skipped=934764  Attempted=1285056
# Inserted=352292  Skipped=934764  Attempted=1287056
# Inserted=354292  Skipped=934764  Attempted=1289056
# Inserted=356292  Skipped=934764  Attempted=1291056
# Inserted=358292  Skipped=934764  Attempted=1293056
# Inserted=360293  Skipped=934764  Attempted=1295057
# Inserted=362293  Skipped=934764  Attempted=1297057
# Inserted=364294  Skipped=934764  Attempted=1299058
# Inserted=366294  Skipped=934764  Attempted=1301058
# Inserted=368294  Skipped=934764  Attempted=1303058
# Inserted=370297  Skipped=934764  Attempted=1305061
# Inserted=372297  Skipped=934764  Attempted=1307061
# Inserted=374300  Skipped=934764  Attempted=1309064
# Inserted=376300  Skipped=934764  Attempted=1311064
# Inserted=378300  Skipped=934764  Attempted=1313064
# Inserted=380300  Skipped=934764  Attempted=1315064
# Inserted=382300  Skipped=934764  Attempted=1317064
# Inserted=384302  Skipped=934764  Attempted=1319066
# Inserted=386302  Skipped=934764  Attempted=1321066
# Inserted=388305  Skipped=934764  Attempted=1323069
# Inserted=390305  Skipped=934764  Attempted=1325069
# Inserted=392306  Skipped=934764  Attempted=1327070
# Inserted=394307  Skipped=934764  Attempted=1329071
# Inserted=396314  Skipped=934764  Attempted=1331078
# Inserted=398316  Skipped=934764  Attempted=1333080
# Inserted=400316  Skipped=934764  Attempted=1335080
# Inserted=402316  Skipped=934764  Attempted=1337080
# Inserted=404319  Skipped=934764  Attempted=1339083
# Inserted=406322  Skipped=934764  Attempted=1341086
# Inserted=408325  Skipped=934764  Attempted=1343089
# Inserted=410327  Skipped=934764  Attempted=1345091
# Inserted=412328  Skipped=934764  Attempted=1347092
# Inserted=414331  Skipped=934764  Attempted=1349095
# Inserted=416334  Skipped=934764  Attempted=1351098
# Inserted=418338  Skipped=934764  Attempted=1353102
# Inserted=420339  Skipped=934764  Attempted=1355103
# Inserted=422341  Skipped=934764  Attempted=1357105
# Inserted=424344  Skipped=934764  Attempted=1359108
# Inserted=426358  Skipped=934764  Attempted=1361122
# Inserted=428358  Skipped=934764  Attempted=1363122
# Inserted=430358  Skipped=934764  Attempted=1365122
# Inserted=432358  Skipped=934764  Attempted=1367122
# Inserted=434358  Skipped=934764  Attempted=1369122
# Inserted=436362  Skipped=934764  Attempted=1371126
# Inserted=438365  Skipped=934764  Attempted=1373129
# Inserted=558465  Skipped=934764  Attempted=1493229
# Inserted=560467  Skipped=934764  Attempted=1495231
# Inserted=562470  Skipped=934764  Attempted=1497234
# Inserted=564472  Skipped=934764  Attempted=1499236
# Inserted=566474  Skipped=934764  Attempted=1501238
# Inserted=568477  Skipped=934764  Attempted=1503241
# Inserted=570477  Skipped=934764  Attempted=1505241
# Inserted=572480  Skipped=934764  Attempted=1507244
# Inserted=574480  Skipped=934764  Attempted=1509244
# Inserted=576480  Skipped=934764  Attempted=1511244
# Inserted=578482  Skipped=934764  Attempted=1513246
# Inserted=580483  Skipped=934764  Attempted=1515247
# Inserted=582485  Skipped=934764  Attempted=1517249
# Inserted=584488  Skipped=934764  Attempted=1519252
# Inserted=586489  Skipped=934764  Attempted=1521253
# Inserted=588490  Skipped=934764  Attempted=1523254
# Inserted=590492  Skipped=934764  Attempted=1525256
# Inserted=592493  Skipped=934764  Attempted=1527257
# Inserted=594493  Skipped=934764  Attempted=1529257
# Inserted=596497  Skipped=934764  Attempted=1531261
# Inserted=598497  Skipped=934764  Attempted=1533261
# Inserted=600497  Skipped=934764  Attempted=1535261
# Inserted=602500  Skipped=934764  Attempted=1537264
# Inserted=604500  Skipped=934764  Attempted=1539264
# Inserted=606503  Skipped=934764  Attempted=1541267
# Inserted=608507  Skipped=934764  Attempted=1543271
# Inserted=610507  Skipped=934764  Attempted=1545271
# Inserted=612508  Skipped=934764  Attempted=1547272
# Inserted=614508  Skipped=934764  Attempted=1549272
# Inserted=616508  Skipped=934764  Attempted=1551272
# Inserted=618510  Skipped=934764  Attempted=1553274
# Inserted=620514  Skipped=934764  Attempted=1555278
# Inserted=622515  Skipped=934764  Attempted=1557279
# Inserted=624515  Skipped=934764  Attempted=1559279
# Inserted=626515  Skipped=934764  Attempted=1561279
# Inserted=628515  Skipped=934764  Attempted=1563279
# Inserted=630518  Skipped=934764  Attempted=1565282
# Inserted=632518  Skipped=934764  Attempted=1567282
# Inserted=634520  Skipped=934764  Attempted=1569284
# Inserted=636520  Skipped=934764  Attempted=1571284
# Inserted=638524  Skipped=934764  Attempted=1573288
# Inserted=640524  Skipped=934764  Attempted=1575288
# Inserted=642524  Skipped=934764  Attempted=1577288
# Inserted=644525  Skipped=934764  Attempted=1579289
# Inserted=646525  Skipped=934764  Attempted=1581289
# Inserted=648528  Skipped=934764  Attempted=1583292
# Inserted=650528  Skipped=934764  Attempted=1585292
# Inserted=652532  Skipped=934764  Attempted=1587296
# Inserted=654535  Skipped=934764  Attempted=1589299
# Inserted=656560  Skipped=934764  Attempted=1591324
# Inserted=658560  Skipped=934764  Attempted=1593324
# Inserted=660562  Skipped=934764  Attempted=1595326
# Inserted=662564  Skipped=934764  Attempted=1597328
# Inserted=664564  Skipped=934764  Attempted=1599328
# Inserted=666566  Skipped=934764  Attempted=1601330
# Inserted=668569  Skipped=934764  Attempted=1603333
# Inserted=670569  Skipped=934764  Attempted=1605333
# Inserted=672570  Skipped=934764  Attempted=1607334
# Inserted=674571  Skipped=934764  Attempted=1609335
# Inserted=1379252  Skipped=934764  Attempted=2314016
# Inserted=1381252  Skipped=934764  Attempted=2316016
# Inserted=1383253  Skipped=934764  Attempted=2318017
# Inserted=1385261  Skipped=934764  Attempted=2320025
# Inserted=1387262  Skipped=934764  Attempted=2322026
# Inserted=1389263  Skipped=934764  Attempted=2324027
# Inserted=1391263  Skipped=934764  Attempted=2326027
# Inserted=1393263  Skipped=934764  Attempted=2328027
# Inserted=1395264  Skipped=934764  Attempted=2330028
# Inserted=1397267  Skipped=934764  Attempted=2332031
# Inserted=1399267  Skipped=934764  Attempted=2334031
# Inserted=1401267  Skipped=934764  Attempted=2336031
# Inserted=1403267  Skipped=934764  Attempted=2338031
# Inserted=1405267  Skipped=934764  Attempted=2340031
# Inserted=1407268  Skipped=934764  Attempted=2342032
# Inserted=1409268  Skipped=934764  Attempted=2344032
# Inserted=1411268  Skipped=934764  Attempted=2346032
# Inserted=1413282  Skipped=934764  Attempted=2348046
# Inserted=1415282  Skipped=934764  Attempted=2350046
# Inserted=1417285  Skipped=934764  Attempted=2352049
# Inserted=1419285  Skipped=934764  Attempted=2354049
# Inserted=1421285  Skipped=934764  Attempted=2356049
# Inserted=1423286  Skipped=934764  Attempted=2358050
# Inserted=1425287  Skipped=934764  Attempted=2360051
# Inserted=1427290  Skipped=934764  Attempted=2362054
# Inserted=1429293  Skipped=934764  Attempted=2364057
# Inserted=1431293  Skipped=934764  Attempted=2366057
# Inserted=1433294  Skipped=934764  Attempted=2368058
# Inserted=1435297  Skipped=934764  Attempted=2370061
# Inserted=1437298  Skipped=934764  Attempted=2372062
# Inserted=1439298  Skipped=934764  Attempted=2374062
# Inserted=1441298  Skipped=934764  Attempted=2376062
# Inserted=1443300  Skipped=934764  Attempted=2378064
# Inserted=1445303  Skipped=934764  Attempted=2380067
# Inserted=1447305  Skipped=934764  Attempted=2382069
# Inserted=1449306  Skipped=934764  Attempted=2384070
# Inserted=1451309  Skipped=934764  Attempted=2386073
# Inserted=1453310  Skipped=934764  Attempted=2388074
# Inserted=1455311  Skipped=934764  Attempted=2390075
# Inserted=1457314  Skipped=934764  Attempted=2392078
# Inserted=1459317  Skipped=934764  Attempted=2394081
# Inserted=1461318  Skipped=934764  Attempted=2396082
# Inserted=1463320  Skipped=934764  Attempted=2398084
# Inserted=1465320  Skipped=934764  Attempted=2400084
# Inserted=1467321  Skipped=934764  Attempted=2402085
# Inserted=1469323  Skipped=934764  Attempted=2404087
# Inserted=1471323  Skipped=934764  Attempted=2406087
# Inserted=1473324  Skipped=934764  Attempted=2408088
# Inserted=1475325  Skipped=934764  Attempted=2410089
# Inserted=1477329  Skipped=934764  Attempted=2412093
# Inserted=1479331  Skipped=934764  Attempted=2414095
# Inserted=1481335  Skipped=934764  Attempted=2416099
# Inserted=1483337  Skipped=934764  Attempted=2418101
# Inserted=1485340  Skipped=934764  Attempted=2420104
# Inserted=1487342  Skipped=934764  Attempted=2422106
# Inserted=1489342  Skipped=934764  Attempted=2424106
# Inserted=1491344  Skipped=934764  Attempted=2426108
# Inserted=1493344  Skipped=934764  Attempted=2428108
# Inserted=1495346  Skipped=934764  Attempted=2430110
# Inserted=1497346  Skipped=934764  Attempted=2432110
# Inserted=1499346  Skipped=934764  Attempted=2434110
# Inserted=1501350  Skipped=934764  Attempted=2436114
# Inserted=1503351  Skipped=934764  Attempted=2438115
# Inserted=1505352  Skipped=934764  Attempted=2440116
# Inserted=1507353  Skipped=934764  Attempted=2442117
# Inserted=1509355  Skipped=934764  Attempted=2444119
# Inserted=1511355  Skipped=934764  Attempted=2446119
# Inserted=1513357  Skipped=934764  Attempted=2448121
# Inserted=1515361  Skipped=934764  Attempted=2450125
# Inserted=1517365  Skipped=934764  Attempted=2452129
# Inserted=1519367  Skipped=934764  Attempted=2454131
# Inserted=1521367  Skipped=934764  Attempted=2456131
# Inserted=1523371  Skipped=934764  Attempted=2458135
# Inserted=1525372  Skipped=934764  Attempted=2460136
# Inserted=1527376  Skipped=934764  Attempted=2462140
# Inserted=1529377  Skipped=934764  Attempted=2464141
# Inserted=1531381  Skipped=934764  Attempted=2466145
# Inserted=1533381  Skipped=934764  Attempted=2468145
# Inserted=1535382  Skipped=934764  Attempted=2470146
# Inserted=1537386  Skipped=934764  Attempted=2472150
# Inserted=1539387  Skipped=934764  Attempted=2474151
# Inserted=1541387  Skipped=934764  Attempted=2476151
# Inserted=1543387  Skipped=934764  Attempted=2478151
# Inserted=1545387  Skipped=934764  Attempted=2480151
# Inserted=1547388  Skipped=934764  Attempted=2482152
# Inserted=1549391  Skipped=934764  Attempted=2484155
# Inserted=1551393  Skipped=934764  Attempted=2486157
# Inserted=1553395  Skipped=934764  Attempted=2488159
# Inserted=1555398  Skipped=934764  Attempted=2490162
# Inserted=1557401  Skipped=934764  Attempted=2492165
# Inserted=1559405  Skipped=934764  Attempted=2494169
# Inserted=1561406  Skipped=934764  Attempted=2496170
# Inserted=1563407  Skipped=934764  Attempted=2498171
# Inserted=1565409  Skipped=934764  Attempted=2500173
# Inserted=1567413  Skipped=934764  Attempted=2502177
# Inserted=1569416  Skipped=934764  Attempted=2504180
# Inserted=1571418  Skipped=934764  Attempted=2506182
# Inserted=1573419  Skipped=934764  Attempted=2508183
# Inserted=1575419  Skipped=934764  Attempted=2510183
# Inserted=1577420  Skipped=934764  Attempted=2512184
# Inserted=1579420  Skipped=934764  Attempted=2514184
# Inserted=1581423  Skipped=934764  Attempted=2516187
# Inserted=1583423  Skipped=934764  Attempted=2518187
# Inserted=1585423  Skipped=934764  Attempted=2520187
# Inserted=1587423  Skipped=934764  Attempted=2522187
# Inserted=1589425  Skipped=934764  Attempted=2524189
# Inserted=1591428  Skipped=934764  Attempted=2526192
# Inserted=1593429  Skipped=934764  Attempted=2528193
# Inserted=1595431  Skipped=934764  Attempted=2530195
# Inserted=1597434  Skipped=934764  Attempted=2532198
# Inserted=1599434  Skipped=934764  Attempted=2534198
# Inserted=1601436  Skipped=934764  Attempted=2536200
# Inserted=1603439  Skipped=934764  Attempted=2538203
# Inserted=1605442  Skipped=934764  Attempted=2540206
# Inserted=1607445  Skipped=934764  Attempted=2542209
# Inserted=1609449  Skipped=934764  Attempted=2544213
# Inserted=1611449  Skipped=934764  Attempted=2546213
# Inserted=1613449  Skipped=934764  Attempted=2548213
# Inserted=1615452  Skipped=934764  Attempted=2550216
# Inserted=1617456  Skipped=934764  Attempted=2552220
# Inserted=1619459  Skipped=934764  Attempted=2554223
# Inserted=1621461  Skipped=934764  Attempted=2556225
# Inserted=1623463  Skipped=934764  Attempted=2558227
# Inserted=1625463  Skipped=934764  Attempted=2560227
# Inserted=1627463  Skipped=934764  Attempted=2562227
# Inserted=1629463  Skipped=934764  Attempted=2564227
# Inserted=1631466  Skipped=934764  Attempted=2566230
# Inserted=1633468  Skipped=934764  Attempted=2568232
# Inserted=1635468  Skipped=934764  Attempted=2570232
# Inserted=1637468  Skipped=934764  Attempted=2572232
# Inserted=1639469  Skipped=934764  Attempted=2574233
# Inserted=1641470  Skipped=934764  Attempted=2576234
# Inserted=1643474  Skipped=934764  Attempted=2578238
# Inserted=1645497  Skipped=934764  Attempted=2580261
# Inserted=1647497  Skipped=934764  Attempted=2582261
# Inserted=1649499  Skipped=934764  Attempted=2584263
# Inserted=1651500  Skipped=934764  Attempted=2586264
# Inserted=1653503  Skipped=934764  Attempted=2588267
# Inserted=1655504  Skipped=934764  Attempted=2590268
# Inserted=1657504  Skipped=934764  Attempted=2592268
# Inserted=1659504  Skipped=934764  Attempted=2594268
# Inserted=1661507  Skipped=934764  Attempted=2596271
# Inserted=1663508  Skipped=934764  Attempted=2598272
# Inserted=1665511  Skipped=934764  Attempted=2600275
# Inserted=1667511  Skipped=934764  Attempted=2602275
# Inserted=1669512  Skipped=934764  Attempted=2604276
# Inserted=1671513  Skipped=934764  Attempted=2606277
# Inserted=1673513  Skipped=934764  Attempted=2608277
# Inserted=1675515  Skipped=934764  Attempted=2610279
# Inserted=1677516  Skipped=934764  Attempted=2612280
# Inserted=1679516  Skipped=934764  Attempted=2614280
# Inserted=1681516  Skipped=934764  Attempted=2616280
# Inserted=1683518  Skipped=934764  Attempted=2618282
# Inserted=1685520  Skipped=934764  Attempted=2620284
# Inserted=1687520  Skipped=934764  Attempted=2622284
# Inserted=1689520  Skipped=934764  Attempted=2624284
# Inserted=1691522  Skipped=934764  Attempted=2626286
# Inserted=1693522  Skipped=934764  Attempted=2628286
# Inserted=1695524  Skipped=934764  Attempted=2630288
# Inserted=1697524  Skipped=934764  Attempted=2632288
# Inserted=1699527  Skipped=934764  Attempted=2634291
# Inserted=1701527  Skipped=934764  Attempted=2636291
# Inserted=1703528  Skipped=934764  Attempted=2638292
# Inserted=1705529  Skipped=934764  Attempted=2640293
# Inserted=1707531  Skipped=934764  Attempted=2642295
# Inserted=1709531  Skipped=934764  Attempted=2644295
# Inserted=1711533  Skipped=934764  Attempted=2646297
# Inserted=1713533  Skipped=934764  Attempted=2648297
# Inserted=1715533  Skipped=934764  Attempted=2650297
# Inserted=1717533  Skipped=934764  Attempted=2652297
# Inserted=1833622  Skipped=934764  Attempted=2768386
# Inserted=1835624  Skipped=934764  Attempted=2770388
# Inserted=1837624  Skipped=934764  Attempted=2772388
# Inserted=1839627  Skipped=934764  Attempted=2774391
# Inserted=1841630  Skipped=934764  Attempted=2776394
# Inserted=1843634  Skipped=934764  Attempted=2778398
# Inserted=1845636  Skipped=934764  Attempted=2780400
# Inserted=1847636  Skipped=934764  Attempted=2782400
# Inserted=1849638  Skipped=934764  Attempted=2784402
# Inserted=1851639  Skipped=934764  Attempted=2786403
# Inserted=1853640  Skipped=934764  Attempted=2788404
# Inserted=1855642  Skipped=934764  Attempted=2790406
# Inserted=1857644  Skipped=934764  Attempted=2792408
# Inserted=1859681  Skipped=934764  Attempted=2794445
# Inserted=1861681  Skipped=934764  Attempted=2796445
# Inserted=1863685  Skipped=934764  Attempted=2798449
# Inserted=1865686  Skipped=934764  Attempted=2800450
# Inserted=1867686  Skipped=934764  Attempted=2802450
# Inserted=1869687  Skipped=934764  Attempted=2804451
# Inserted=1871687  Skipped=934764  Attempted=2806451
# Inserted=1873689  Skipped=934764  Attempted=2808453
# Inserted=1875690  Skipped=934764  Attempted=2810454
# Inserted=1877690  Skipped=934764  Attempted=2812454
# Inserted=1879691  Skipped=934764  Attempted=2814455
# Inserted=1881691  Skipped=934764  Attempted=2816455
# Inserted=1883695  Skipped=934764  Attempted=2818459
# Inserted=1885695  Skipped=934764  Attempted=2820459
# Inserted=1887695  Skipped=934764  Attempted=2822459
# Inserted=1889695  Skipped=934764  Attempted=2824459
# Inserted=1891697  Skipped=934764  Attempted=2826461
# Inserted=1893701  Skipped=934764  Attempted=2828465
# Inserted=1895702  Skipped=934764  Attempted=2830466
# Inserted=1897702  Skipped=934764  Attempted=2832466
# Inserted=1899703  Skipped=934764  Attempted=2834467
# Inserted=1901707  Skipped=934764  Attempted=2836471
# Inserted=1903709  Skipped=934764  Attempted=2838473
# Inserted=1905713  Skipped=934764  Attempted=2840477
# Inserted=1907713  Skipped=934764  Attempted=2842477
# Inserted=1909714  Skipped=934764  Attempted=2844478
# Inserted=1911714  Skipped=934764  Attempted=2846478
# Inserted=1913714  Skipped=934764  Attempted=2848478
# Inserted=1915714  Skipped=934764  Attempted=2850478
# Inserted=1917714  Skipped=934764  Attempted=2852478
# Inserted=1919714  Skipped=934764  Attempted=2854478
# Inserted=1921714  Skipped=934764  Attempted=2856478
# Inserted=1923714  Skipped=934764  Attempted=2858478
# Inserted=1925714  Skipped=934764  Attempted=2860478
# Inserted=1927717  Skipped=934764  Attempted=2862481
# Inserted=1929720  Skipped=934764  Attempted=2864484
# Inserted=1931720  Skipped=934764  Attempted=2866484
# Inserted=1933720  Skipped=934764  Attempted=2868484
# Inserted=1935723  Skipped=934764  Attempted=2870487
# Inserted=1936134  Skipped=934764  Attempted=2870898
#
# Done.
# Row groups       : 1
# Rows seen        : 937711
# Chunks seen      : 2870898
# Attempted chunks : 2870898
# Inserted chunks  : 1936134
# Skipped existing : 934764
